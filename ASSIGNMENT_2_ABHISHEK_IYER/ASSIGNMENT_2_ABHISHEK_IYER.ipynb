# %% [markdown]
# # Assignment 2: Containers
#
# **Deadline: Tuesday, September 20, 2022 before 17:00**
#
# - Please name your files:
#     * ASSIGNMENT_2_FIRSTNAME_LASTNAME.ipynb
#     * assignment2_utils.py
# - Please store the two files in a folder called ASSIGNMENT_2_FIRSTNAME_LASTNAME
# - Please zip your folder and please follow the following naming convention for the zip file: ASSIGNMENT_2_FIRSTNAME_LASTNAME.zip
# - Please submit your assignment on Canvas: Assignment 2
# - If you have **questions** about this topic, please contact us **(cltl.python.course@gmail.com)**. Questions and answers will be collected on Piazza, so please check if your question has already been answered first.
#
# In this block, we covered the following chapters:
# - Chapter 05 - Core concepts of containers
# - Chapter 06 - Lists
# - Chapter 07 - Sets
# - Chapter 08 - Comparison of lists and sets
# - Chapter 09 - Looping over containers.
# - Chapter 10 - Dictionaries
# - Chapter 11 - Functions and scope
#
# In this assignment, you will be asked to show what you have learned from the topics above!
#
# **Finding solutions online**
#
# Very often, you can find good solutions online. We encourage you to use online resources when you get stuck. However, please always try to understand the code you find and indicate that it is not your own. Use the following format to mark code written by someone else:
#
# ###Taken from [link] [date]
#
# [code]
#
# \###
#
# Please use a similar format to indicate that you have worked with a classmate (e.g. mention the name instead of the link).
#
# *Please stick to this strategy for all course assignments.*

# %% [markdown]
# ## Exercise 1: Beersong
# *99 Bottles of Beer* is a traditional song in the United States and Canada. Write a python program that generates the lyrics to the song.

# %% [markdown]
# The song's simple lyrics are as follows:
#
#     99 bottles of beer on the wall,
#     99 bottles of beer.
#     Take one down, pass it around,
#     98 bottles of beer on the wall.
#
# The same verse is repeated, each time with one fewer bottle. The song
# is completed when the singer or singers reach zero. After the last bottle
# is taken down and passed around, there is a special verse:
#
#     No more bottles of beer on the wall,
#     no more bottles of beer.
#     Go to the store and buy some more,
#     99 bottles of beer on the wall.

# %% [markdown]
# Notes:
#
# * Leave a blank line between verses.
# * Make sure that you print the singular form of "bottles" when the counter is at one.

# %% [markdown]
# Hint:
#
# * While debugging the program, start from a small number, and
# change it to 100 when you are done (as shown below).
# * Use variables to prevent code repetition
#
# You can use the following code snippet as a start:

# %%
for number in range(99, 0, -1): # change 4 to 99 when you're done with debugging
    if number == 2:
        print(f'{number} bottles of beer on the wall,\n{number} bottles of beer.\nTake one down, pass it around,\n{number-1} bottle of beer on the wall.\n')
    elif number == 1:
        print(f'{number} bottles of beer on the wall,\n{number} bottles of beer.\nTake one down, pass it around,\nNo more bottles of beer on the wall.\n')
        print('No more bottles of beer on the wall,\nno more bottles of beer.\nGo to the store and buy some more,\n99 bottles of beer on the wall.\n')
    else:
        print(f'{number} bottles of beer on the wall,\n{number} bottles of beer.\nTake one down, pass it around,\n{number-1} bottles of beer on the wall.\n')
# Out:
# 99 bottles of beer on the wall,
# 99 bottles of beer.
# Take one down, pass it around,
# 98 bottles of beer on the wall.
#
# 98 bottles of beer on the wall,
# 98 bottles of beer.
# Take one down, pass it around,
# 97 bottles of beer on the wall.
#
# 97 bottles of beer on the wall,
# 97 bottles of beer.
# Take one down, pass it around,
# 96 bottles of beer on the wall.
#
# 96 bottles of beer on the wall,
# 96 bottles of beer.
# Take one down, pass it around,
# 95 bottles of beer on the wall.
#
# 95 bottles of beer on the wall,
# 95 bottles of beer.
# Take one down, pass it around,
# 94 bottles of beer on the wall.
#
# 94 bottles of beer on the wall,
# 94 bottles of beer.
# Take one down, pass it around,
# 93 bottles of beer on the wall.
#
# 93 bottles of beer on the wall,
# 93 bottles of beer.
# Take one down, pass it around,
# 92 bottles of beer on the wall.
#
# 92 bottles of beer on the wall,
# 92 bottles of beer.
# Take one down, pass it around,
# 91 bottles of beer on the wall.
#
# 91 bottles of beer on the wall,
# 91 bottles of beer.
# Take one down, pass it around,
# 90 bottles of beer on the wall.
#
# 90 bottles of beer on the wall,
# 90 bottles of beer.
# Take one down, pass it around,
# 89 bottles of beer on the wall.
#
# 89 bottles of beer on the wall,
# 89 bottles of beer.
# Take one down, pass it around,
# 88 bottles of beer on the wall.
#
# 88 bottles of beer on the wall,
# 88 bottles of beer.
# Take one down, pass it around,
# 87 bottles of beer on the wall.
#
# 87 bottles of beer on the wall,
# 87 bottles of beer.
# Take one down, pass it around,
# 86 bottles of beer on the wall.
#
# 86 bottles of beer on the wall,
# 86 bottles of beer.
# Take one down, pass it around,
# 85 bottles of beer on the wall.
#
# 85 bottles of beer on the wall,
# 85 bottles of beer.
# Take one down, pass it around,
# 84 bottles of beer on the wall.
#
# 84 bottles of beer on the wall,
# 84 bottles of beer.
# Take one down, pass it around,
# 83 bottles of beer on the wall.
#
# 83 bottles of beer on the wall,
# 83 bottles of beer.
# Take one down, pass it around,
# 82 bottles of beer on the wall.
#
# 82 bottles of beer on the wall,
# 82 bottles of beer.
# Take one down, pass it around,
# 81 bottles of beer on the wall.
#
# 81 bottles of beer on the wall,
# 81 bottles of beer.
# Take one down, pass it around,
# 80 bottles of beer on the wall.
#
# 80 bottles of beer on the wall,
# 80 bottles of beer.
# Take one down, pass it around,
# 79 bottles of beer on the wall.
#
# 79 bottles of beer on the wall,
# 79 bottles of beer.
# Take one down, pass it around,
# 78 bottles of beer on the wall.
#
# 78 bottles of beer on the wall,
# 78 bottles of beer.
# Take one down, pass it around,
# 77 bottles of beer on the wall.
#
# 77 bottles of beer on the wall,
# 77 bottles of beer.
# Take one down, pass it around,
# 76 bottles of beer on the wall.
#
# 76 bottles of beer on the wall,
# 76 bottles of beer.
# Take one down, pass it around,
# 75 bottles of beer on the wall.
#
# 75 bottles of beer on the wall,
# 75 bottles of beer.
# Take one down, pass it around,
# 74 bottles of beer on the wall.
#
# 74 bottles of beer on the wall,
# 74 bottles of beer.
# Take one down, pass it around,
# 73 bottles of beer on the wall.
#
# 73 bottles of beer on the wall,
# 73 bottles of beer.
# Take one down, pass it around,
# 72 bottles of beer on the wall.
#
# 72 bottles of beer on the wall,
# 72 bottles of beer.
# Take one down, pass it around,
# 71 bottles of beer on the wall.
#
# 71 bottles of beer on the wall,
# 71 bottles of beer.
# Take one down, pass it around,
# 70 bottles of beer on the wall.
#
# 70 bottles of beer on the wall,
# 70 bottles of beer.
# Take one down, pass it around,
# 69 bottles of beer on the wall.
#
# 69 bottles of beer on the wall,
# 69 bottles of beer.
# Take one down, pass it around,
# 68 bottles of beer on the wall.
#
# 68 bottles of beer on the wall,
# 68 bottles of beer.
# Take one down, pass it around,
# 67 bottles of beer on the wall.
#
# 67 bottles of beer on the wall,
# 67 bottles of beer.
# Take one down, pass it around,
# 66 bottles of beer on the wall.
#
# 66 bottles of beer on the wall,
# 66 bottles of beer.
# Take one down, pass it around,
# 65 bottles of beer on the wall.
#
# 65 bottles of beer on the wall,
# 65 bottles of beer.
# Take one down, pass it around,
# 64 bottles of beer on the wall.
#
# 64 bottles of beer on the wall,
# 64 bottles of beer.
# Take one down, pass it around,
# 63 bottles of beer on the wall.
#
# 63 bottles of beer on the wall,
# 63 bottles of beer.
# Take one down, pass it around,
# 62 bottles of beer on the wall.
#
# 62 bottles of beer on the wall,
# 62 bottles of beer.
# Take one down, pass it around,
# 61 bottles of beer on the wall.
#
# 61 bottles of beer on the wall,
# 61 bottles of beer.
# Take one down, pass it around,
# 60 bottles of beer on the wall.
#
# 60 bottles of beer on the wall,
# 60 bottles of beer.
# Take one down, pass it around,
# 59 bottles of beer on the wall.
#
# 59 bottles of beer on the wall,
# 59 bottles of beer.
# Take one down, pass it around,
# 58 bottles of beer on the wall.
#
# 58 bottles of beer on the wall,
# 58 bottles of beer.
# Take one down, pass it around,
# 57 bottles of beer on the wall.
#
# 57 bottles of beer on the wall,
# 57 bottles of beer.
# Take one down, pass it around,
# 56 bottles of beer on the wall.
#
# 56 bottles of beer on the wall,
# 56 bottles of beer.
# Take one down, pass it around,
# 55 bottles of beer on the wall.
#
# 55 bottles of beer on the wall,
# 55 bottles of beer.
# Take one down, pass it around,
# 54 bottles of beer on the wall.
#
# 54 bottles of beer on the wall,
# 54 bottles of beer.
# Take one down, pass it around,
# 53 bottles of beer on the wall.
#
# 53 bottles of beer on the wall,
# 53 bottles of beer.
# Take one down, pass it around,
# 52 bottles of beer on the wall.
#
# 52 bottles of beer on the wall,
# 52 bottles of beer.
# Take one down, pass it around,
# 51 bottles of beer on the wall.
#
# 51 bottles of beer on the wall,
# 51 bottles of beer.
# Take one down, pass it around,
# 50 bottles of beer on the wall.
#
# 50 bottles of beer on the wall,
# 50 bottles of beer.
# Take one down, pass it around,
# 49 bottles of beer on the wall.
#
# 49 bottles of beer on the wall,
# 49 bottles of beer.
# Take one down, pass it around,
# 48 bottles of beer on the wall.
#
# 48 bottles of beer on the wall,
# 48 bottles of beer.
# Take one down, pass it around,
# 47 bottles of beer on the wall.
#
# 47 bottles of beer on the wall,
# 47 bottles of beer.
# Take one down, pass it around,
# 46 bottles of beer on the wall.
#
# 46 bottles of beer on the wall,
# 46 bottles of beer.
# Take one down, pass it around,
# 45 bottles of beer on the wall.
#
# 45 bottles of beer on the wall,
# 45 bottles of beer.
# Take one down, pass it around,
# 44 bottles of beer on the wall.
#
# 44 bottles of beer on the wall,
# 44 bottles of beer.
# Take one down, pass it around,
# 43 bottles of beer on the wall.
#
# 43 bottles of beer on the wall,
# 43 bottles of beer.
# Take one down, pass it around,
# 42 bottles of beer on the wall.
#
# 42 bottles of beer on the wall,
# 42 bottles of beer.
# Take one down, pass it around,
# 41 bottles of beer on the wall.
#
# 41 bottles of beer on the wall,
# 41 bottles of beer.
# Take one down, pass it around,
# 40 bottles of beer on the wall.
#
# 40 bottles of beer on the wall,
# 40 bottles of beer.
# Take one down, pass it around,
# 39 bottles of beer on the wall.
#
# 39 bottles of beer on the wall,
# 39 bottles of beer.
# Take one down, pass it around,
# 38 bottles of beer on the wall.
#
# 38 bottles of beer on the wall,
# 38 bottles of beer.
# Take one down, pass it around,
# 37 bottles of beer on the wall.
#
# 37 bottles of beer on the wall,
# 37 bottles of beer.
# Take one down, pass it around,
# 36 bottles of beer on the wall.
#
# 36 bottles of beer on the wall,
# 36 bottles of beer.
# Take one down, pass it around,
# 35 bottles of beer on the wall.
#
# 35 bottles of beer on the wall,
# 35 bottles of beer.
# Take one down, pass it around,
# 34 bottles of beer on the wall.
#
# 34 bottles of beer on the wall,
# 34 bottles of beer.
# Take one down, pass it around,
# 33 bottles of beer on the wall.
#
# 33 bottles of beer on the wall,
# 33 bottles of beer.
# Take one down, pass it around,
# 32 bottles of beer on the wall.
#
# 32 bottles of beer on the wall,
# 32 bottles of beer.
# Take one down, pass it around,
# 31 bottles of beer on the wall.
#
# 31 bottles of beer on the wall,
# 31 bottles of beer.
# Take one down, pass it around,
# 30 bottles of beer on the wall.
#
# 30 bottles of beer on the wall,
# 30 bottles of beer.
# Take one down, pass it around,
# 29 bottles of beer on the wall.
#
# 29 bottles of beer on the wall,
# 29 bottles of beer.
# Take one down, pass it around,
# 28 bottles of beer on the wall.
#
# 28 bottles of beer on the wall,
# 28 bottles of beer.
# Take one down, pass it around,
# 27 bottles of beer on the wall.
#
# 27 bottles of beer on the wall,
# 27 bottles of beer.
# Take one down, pass it around,
# 26 bottles of beer on the wall.
#
# 26 bottles of beer on the wall,
# 26 bottles of beer.
# Take one down, pass it around,
# 25 bottles of beer on the wall.
#
# 25 bottles of beer on the wall,
# 25 bottles of beer.
# Take one down, pass it around,
# 24 bottles of beer on the wall.
#
# 24 bottles of beer on the wall,
# 24 bottles of beer.
# Take one down, pass it around,
# 23 bottles of beer on the wall.
#
# 23 bottles of beer on the wall,
# 23 bottles of beer.
# Take one down, pass it around,
# 22 bottles of beer on the wall.
#
# 22 bottles of beer on the wall,
# 22 bottles of beer.
# Take one down, pass it around,
# 21 bottles of beer on the wall.
#
# 21 bottles of beer on the wall,
# 21 bottles of beer.
# Take one down, pass it around,
# 20 bottles of beer on the wall.
#
# 20 bottles of beer on the wall,
# 20 bottles of beer.
# Take one down, pass it around,
# 19 bottles of beer on the wall.
#
# 19 bottles of beer on the wall,
# 19 bottles of beer.
# Take one down, pass it around,
# 18 bottles of beer on the wall.
#
# 18 bottles of beer on the wall,
# 18 bottles of beer.
# Take one down, pass it around,
# 17 bottles of beer on the wall.
#
# 17 bottles of beer on the wall,
# 17 bottles of beer.
# Take one down, pass it around,
# 16 bottles of beer on the wall.
#
# 16 bottles of beer on the wall,
# 16 bottles of beer.
# Take one down, pass it around,
# 15 bottles of beer on the wall.
#
# 15 bottles of beer on the wall,
# 15 bottles of beer.
# Take one down, pass it around,
# 14 bottles of beer on the wall.
#
# 14 bottles of beer on the wall,
# 14 bottles of beer.
# Take one down, pass it around,
# 13 bottles of beer on the wall.
#
# 13 bottles of beer on the wall,
# 13 bottles of beer.
# Take one down, pass it around,
# 12 bottles of beer on the wall.
#
# 12 bottles of beer on the wall,
# 12 bottles of beer.
# Take one down, pass it around,
# 11 bottles of beer on the wall.
#
# 11 bottles of beer on the wall,
# 11 bottles of beer.
# Take one down, pass it around,
# 10 bottles of beer on the wall.
#
# 10 bottles of beer on the wall,
# 10 bottles of beer.
# Take one down, pass it around,
# 9 bottles of beer on the wall.
#
# 9 bottles of beer on the wall,
# 9 bottles of beer.
# Take one down, pass it around,
# 8 bottles of beer on the wall.
#
# 8 bottles of beer on the wall,
# 8 bottles of beer.
# Take one down, pass it around,
# 7 bottles of beer on the wall.
#
# 7 bottles of beer on the wall,
# 7 bottles of beer.
# Take one down, pass it around,
# 6 bottles of beer on the wall.
#
# 6 bottles of beer on the wall,
# 6 bottles of beer.
# Take one down, pass it around,
# 5 bottles of beer on the wall.
#
# 5 bottles of beer on the wall,
# 5 bottles of beer.
# Take one down, pass it around,
# 4 bottles of beer on the wall.
#
# 4 bottles of beer on the wall,
# 4 bottles of beer.
# Take one down, pass it around,
# 3 bottles of beer on the wall.
#
# 3 bottles of beer on the wall,
# 3 bottles of beer.
# Take one down, pass it around,
# 2 bottles of beer on the wall.
#
# 2 bottles of beer on the wall,
# 2 bottles of beer.
# Take one down, pass it around,
# 1 bottle of beer on the wall.
#
# 1 bottles of beer on the wall,
# 1 bottles of beer.
# Take one down, pass it around,
# No more bottles of beer on the wall.
#
# No more bottles of beer on the wall,
# no more bottles of beer.
# Go to the store and buy some more,
# 99 bottles of beer on the wall.

# %% [markdown]
# ## Exercise 2: list methods

# %% [markdown]
# In this exercise, we will focus on the following list methods:
#
# a.) append
#
# b.) count
#
# c.) index
#
# d.) insert
#
# e.) pop
#
# For each of the aforementioned list methods:
#
# * explain the positional parameters
# * explain the keyword parameters
# * you can exclude *self* from your explanation
# * explain what the goal of the method is and what data type it returns, e.g., string, list, set, etc.
# * give a working example. Provide also an example by providing a value for keyword parameters (assuming the method has one or more keyword parameters).

# %% [markdown]
# ### a) Append
# The append method has one positional parameter.
# It has no keyword parameter.
# The goal of the method is to help add value (be it of any datatype) to the end of the list and it returns no value.

# %%
list1 = ['a','b']
list1.append('c')
print(list1)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ### b) Count
# The count method has one positional parameter and it has no keyword parameter. The goal of the method is to get the count of the number of times a certain object appears in the list and it returns INT datatype.

# %%
list1.count('c')
# Out:
# 1

# %% [markdown]
# ### c) Index
# The index method has three positional parameters where the first parameter is the element we want to search in the list and the next parameter takes the start position, i.e., the position in the list from where the search for the element should start and the next parameter takes the end position, i.e., the position in the list where the search for the element should end. The start end end parameters are optional. It has no keyword parameter. The goal of the method is to aid in searching for given element within a list and returning the index of the first occurance of that element. If start and end parameters are not defined, the default is 0 and -1 respectively. It returns INT

# %%
list1.index('b',1,2)
# Out:
# 1

# %% [markdown]
# ### d) Insert
# The insert method has two positional parameters where the first parameter takes the index at which an element is to inserted in the list and the second parameter is the element that is to be inserted into the list. It has no keyword parameter. The goal of the method is to insert a certain element at any given position in the list. It returns no value.

# %%
list1.insert(1,'d')
list1
# Out:
# ['a', 'd', 'b', 'c']

# %% [markdown]
# ### e) Pop
# The pop method has one positional parameter which is optional, the parameter takes the index value and the element at that index in the list is popped (removed). It has no keyword parameters. The goal of the method is to pop (i.e. remove) an element from the list, if the paramter is not defined, pop by default removes the last element of the list. It returns the value of the element that is popped.

# %%
list1.pop()
list1
# Out:
# ['a', 'd', 'b']

# %% [markdown]
# ## Exercise 3: set methods

# %% [markdown]
# In this exercise, we will focus on the following set methods:
# * update
# * pop
# * remove
# * clear
#
# For each of the aforementioned set methods:
#
# * explain the positional parameters
# * explain the keyword parameters
# * you can exclude *self* from your explanation
# * explain what the goal of the method is and what data type it returns, e.g., string, list, set, etc.
# * give a working example. Provide also an example by providing a value for keyword parameters (assuming the method has one or more keyword parameters).

# %% [markdown]
# ### a) Update
# The update method can have multiple positional parameters which can be a set, list, tuples or a dictionary. It has no keyword parameter. The goal of the method is to add elements from a set,list,tuples or dictionary to the set. It returns no value

# %%
set1 = {'a', 'b', 'c'}
set2 = {'A', 'B', 'C'}
set1.update(set2)
set1
# Out:
# {'A', 'B', 'C', 'a', 'b', 'c'}

# %% [markdown]
# ### b) Pop
# The pop method has no positional or keyword parameters. The goal of the function is pop a random element from the set. It returns the value of the element that has been popped

# %%
set1.pop()
set1
# Out:
# {'A', 'B', 'C', 'b', 'c'}

# %% [markdown]
# ### c) Remove
# The remove method has one positional parameter which takes the value of the element that is to be removed from  the set and no keyword parameter. The goal of the method is to remove the specified element from the set. It returns no value.

# %%
set1.remove('c')
set1
# Out:
# {'A', 'B', 'C', 'b'}

# %% [markdown]
# ### d) Clear
# The clear method takes no positional or keyword parameters. The goal of the method is to clear all the elements from the set. It  returns no value

# %%
set1.clear()
set1
# Out:
# set()

# %% [markdown]
# ## Exercise 4: Analyzing vocabulary using sets
# Please consider the following two texts:

# %% [markdown]
# These stories were copied from [here](http://www.english-for-students.com/).

# %%
a_story = """In a far away kingdom, there was a river. This river was home to many golden swans. The swans spent most of their time on the banks of the river. Every six months, the swans would leave a golden feather as a fee for using the lake. The soldiers of the kingdom would collect the feathers and deposit them in the royal treasury. 
One day, a homeless bird saw the river. "The water in this river seems so cool and soothing. I will make my home here," thought the bird. 
As soon as the bird settled down near the river, the golden swans noticed her. They came shouting. "This river belongs to us. We pay a golden feather to the King to use this river. You can not live here." 
"I am homeless, brothers. I too will pay the rent. Please give me shelter," the bird pleaded. "How will you pay the rent? You do not have golden feathers," said the swans laughing. They further added, "Stop dreaming and leave once." The humble bird pleaded many times. But the arrogant swans drove the bird away. 
"I will teach them a lesson!" decided the humiliated bird. 
She went to the King and said, "O King! The swans in your river are impolite and unkind. I begged for shelter but they said that they had purchased the river with golden feathers." 
The King was angry with the arrogant swans for having insulted the homeless bird. He ordered his soldiers to bring the arrogant swans to his court. In no time, all the golden swans were brought to the King’s court. 
"Do you think the royal treasury depends upon your golden feathers? You can not decide who lives by the river. Leave the river at once or you all will be beheaded!" shouted the King. 
The swans shivered with fear on hearing the King. They flew away never to return. The bird built her home near the river and lived there happily forever. The bird gave shelter to all other birds in the river. """
print(a_story)
# Out:
# In a far away kingdom, there was a river. This river was home to many golden swans. The swans spent most of their time on the banks of the river. Every six months, the swans would leave a golden feather as a fee for using the lake. The soldiers of the kingdom would collect the feathers and deposit them in the royal treasury.
# One day, a homeless bird saw the river. "The water in this river seems so cool and soothing. I will make my home here," thought the bird.
# As soon as the bird settled down near the river, the golden swans noticed her. They came shouting. "This river belongs to us. We pay a golden feather to the King to use this river. You can not live here."
# "I am homeless, brothers. I too will pay the rent. Please give me shelter," the bird pleaded. "How will you pay the rent? You do not have golden feathers," said the swans laughing. They further added, "Stop dreaming and leave once." The humble bird pleaded many times. But the arrogant swans drove the bird away.
# "I will teach them a lesson!" decided the humiliated bird.
# She went to the King and said, "O King! The swans in your river are impolite and unkind. I begged for shelter but they said that they had purchased the river with golden feathers."
# The King was angry with the arrogant swans for having insulted the homeless bird. He ordered his soldiers to bring the arrogant swans to his court. In no time, all the golden swans were brought to the King’s court.
# "Do you think the royal treasury depends upon your golden feathers? You can not decide who lives by the river. Leave the river at once or you all will be beheaded!" shouted the King.
# The swans shivered with fear on hearing the King. They flew away never to return. The bird built her home near the river and lived there happily forever. The bird gave shelter to all other birds in the river.

# %%
another_story = """Long time ago, there lived a King. He was lazy and liked all the comforts of life. He never carried out his duties as a King. "Our King does not take care of our needs. He also ignores the affairs of his kingdom." The people complained. 
One day, the King went into the forest to hunt. After having wandered for quite sometime, he became thirsty. To his relief, he spotted a lake. As he was drinking water, he suddenly saw a golden swan come out of the lake and perch on a stone. "Oh! A golden swan. I must capture it," thought the King. 
But as soon as he held his bow up, the swan disappeared. And the King heard a voice, "I am the Golden Swan. If you want to capture me, you must come to heaven." 
Surprised, the King said, "Please show me the way to heaven." Do good deeds, serve your people and the messenger from heaven would come to fetch you to heaven," replied the voice. 
The selfish King, eager to capture the Swan, tried doing some good deeds in his Kingdom. "Now, I suppose a messenger will come to take me to heaven," he thought. But, no messenger came. 
The King then disguised himself and went out into the street. There he tried helping an old man. But the old man became angry and said, "You need not try to help. I am in this miserable state because of out selfish King. He has done nothing for his people." 
Suddenly, the King heard the golden swan’s voice, "Do good deeds and you will come to heaven." It dawned on the King that by doing selfish acts, he will not go to heaven. 
He realized that his people needed him and carrying out his duties was the only way to heaven. After that day he became a responsible King. 
"""

# %% [markdown]
# ### Exercise 4a: preprocessing text
# Before analyzing the two texts, we are first going to preprocess them.
# Please use a particular string method multiple times to replace the following characters by empty strings in both **a_story** and **another_story**:
# * newlines: '\n'
# * commas: ','
# * dots: '.'
# * quotes: '"'
#
#
# Please assign the processed texts to the variables **cleaned_story** and **cleaned_another_story**.

# %%
cleaned_story = a_story.replace('\n','').replace(',','').replace('.','').replace('"','')
print(cleaned_story,"\n")
cleaned_another_story = another_story.replace('\n','').replace(',','').replace('.','').replace('"','')
print(cleaned_another_story)
# Out:
# In a far away kingdom there was a river This river was home to many golden swans The swans spent most of their time on the banks of the river Every six months the swans would leave a golden feather as a fee for using the lake The soldiers of the kingdom would collect the feathers and deposit them in the royal treasury One day a homeless bird saw the river The water in this river seems so cool and soothing I will make my home here thought the bird As soon as the bird settled down near the river the golden swans noticed her They came shouting This river belongs to us We pay a golden feather to the King to use this river You can not live here I am homeless brothers I too will pay the rent Please give me shelter the bird pleaded How will you pay the rent? You do not have golden feathers said the swans laughing They further added Stop dreaming and leave once The humble bird pleaded many times But the arrogant swans drove the bird away I will teach them a lesson! decided the humiliated bird She went to the King and said O King! The swans in your river are impolite and unkind I begged for shelter but they said that they had purchased the river with golden feathers The King was angry with the arrogant swans for having insulted the homeless bird He ordered his soldiers to bring the arrogant swans to his court In no time all the golden swans were brought to the King’s court Do you think the royal treasury depends upon your golden feathers? You can not decide who lives by the river Leave the river at once or you all will be beheaded! shouted the King The swans shivered with fear on hearing the King They flew away never to return The bird built her home near the river and lived there happily forever The bird gave shelter to all other birds in the river
#
# Long time ago there lived a King He was lazy and liked all the comforts of life He never carried out his duties as a King Our King does not take care of our needs He also ignores the affairs of his kingdom The people complained One day the King went into the forest to hunt After having wandered for quite sometime he became thirsty To his relief he spotted a lake As he was drinking water he suddenly saw a golden swan come out of the lake and perch on a stone Oh! A golden swan I must capture it thought the King But as soon as he held his bow up the swan disappeared And the King heard a voice I am the Golden Swan If you want to capture me you must come to heaven Surprised the King said Please show me the way to heaven Do good deeds serve your people and the messenger from heaven would come to fetch you to heaven replied the voice The selfish King eager to capture the Swan tried doing some good deeds in his Kingdom Now I suppose a messenger will come to take me to heaven he thought But no messenger came The King then disguised himself and went out into the street There he tried helping an old man But the old man became angry and said You need not try to help I am in this miserable state because of out selfish King He has done nothing for his people Suddenly the King heard the golden swan’s voice Do good deeds and you will come to heaven It dawned on the King that by doing selfish acts he will not go to heaven He realized that his people needed him and carrying out his duties was the only way to heaven After that day he became a responsible King

# %% [markdown]
# #### Exercise 4b: from text to a list
# For each text (**cleaned_story** and **cleaned_another_story**), please use a string method to convert **cleaned_story** and **cleaned_another_story** into lists by splitting using spaces. Please call the lists **list_cleaned_story** and **list_cleaned_another_story**.

# %%
list_cleaned_story = cleaned_story.split(" ")
print(list_cleaned_story,"/n")
list_cleaned_another_story = cleaned_another_story.split(" ")
print(list_cleaned_another_story)
# Out:
# ['In', 'a', 'far', 'away', 'kingdom', 'there', 'was', 'a', 'river', 'This', 'river', 'was', 'home', 'to', 'many', 'golden', 'swans', 'The', 'swans', 'spent', 'most', 'of', 'their', 'time', 'on', 'the', 'banks', 'of', 'the', 'river', 'Every', 'six', 'months', 'the', 'swans', 'would', 'leave', 'a', 'golden', 'feather', 'as', 'a', 'fee', 'for', 'using', 'the', 'lake', 'The', 'soldiers', 'of', 'the', 'kingdom', 'would', 'collect', 'the', 'feathers', 'and', 'deposit', 'them', 'in', 'the', 'royal', 'treasury', 'One', 'day', 'a', 'homeless', 'bird', 'saw', 'the', 'river', 'The', 'water', 'in', 'this', 'river', 'seems', 'so', 'cool', 'and', 'soothing', 'I', 'will', 'make', 'my', 'home', 'here', 'thought', 'the', 'bird', 'As', 'soon', 'as', 'the', 'bird', 'settled', 'down', 'near', 'the', 'river', 'the', 'golden', 'swans', 'noticed', 'her', 'They', 'came', 'shouting', 'This', 'river', 'belongs', 'to', 'us', 'We', 'pay', 'a', 'golden', 'feather', 'to', 'the', 'King', 'to', 'use', 'this', 'river', 'You', 'can', 'not', 'live', 'here', 'I', 'am', 'homeless', 'brothers', 'I', 'too', 'will', 'pay', 'the', 'rent', 'Please', 'give', 'me', 'shelter', 'the', 'bird', 'pleaded', 'How', 'will', 'you', 'pay', 'the', 'rent?', 'You', 'do', 'not', 'have', 'golden', 'feathers', 'said', 'the', 'swans', 'laughing', 'They', 'further', 'added', 'Stop', 'dreaming', 'and', 'leave', 'once', 'The', 'humble', 'bird', 'pleaded', 'many', 'times', 'But', 'the', 'arrogant', 'swans', 'drove', 'the', 'bird', 'away', 'I', 'will', 'teach', 'them', 'a', 'lesson!', 'decided', 'the', 'humiliated', 'bird', 'She', 'went', 'to', 'the', 'King', 'and', 'said', 'O', 'King!', 'The', 'swans', 'in', 'your', 'river', 'are', 'impolite', 'and', 'unkind', 'I', 'begged', 'for', 'shelter', 'but', 'they', 'said', 'that', 'they', 'had', 'purchased', 'the', 'river', 'with', 'golden', 'feathers', 'The', 'King', 'was', 'angry', 'with', 'the', 'arrogant', 'swans', 'for', 'having', 'insulted', 'the', 'homeless', 'bird', 'He', 'ordered', 'his', 'soldiers', 'to', 'bring', 'the', 'arrogant', 'swans', 'to', 'his', 'court', 'In', 'no', 'time', 'all', 'the', 'golden', 'swans', 'were', 'brought', 'to', 'the', 'King’s', 'court', 'Do', 'you', 'think', 'the', 'royal', 'treasury', 'depends', 'upon', 'your', 'golden', 'feathers?', 'You', 'can', 'not', 'decide', 'who', 'lives', 'by', 'the', 'river', 'Leave', 'the', 'river', 'at', 'once', 'or', 'you', 'all', 'will', 'be', 'beheaded!', 'shouted', 'the', 'King', 'The', 'swans', 'shivered', 'with', 'fear', 'on', 'hearing', 'the', 'King', 'They', 'flew', 'away', 'never', 'to', 'return', 'The', 'bird', 'built', 'her', 'home', 'near', 'the', 'river', 'and', 'lived', 'there', 'happily', 'forever', 'The', 'bird', 'gave', 'shelter', 'to', 'all', 'other', 'birds', 'in', 'the', 'river', ''] /n
# ['Long', 'time', 'ago', 'there', 'lived', 'a', 'King', 'He', 'was', 'lazy', 'and', 'liked', 'all', 'the', 'comforts', 'of', 'life', 'He', 'never', 'carried', 'out', 'his', 'duties', 'as', 'a', 'King', 'Our', 'King', 'does', 'not', 'take', 'care', 'of', 'our', 'needs', 'He', 'also', 'ignores', 'the', 'affairs', 'of', 'his', 'kingdom', 'The', 'people', 'complained', 'One', 'day', 'the', 'King', 'went', 'into', 'the', 'forest', 'to', 'hunt', 'After', 'having', 'wandered', 'for', 'quite', 'sometime', 'he', 'became', 'thirsty', 'To', 'his', 'relief', 'he', 'spotted', 'a', 'lake', 'As', 'he', 'was', 'drinking', 'water', 'he', 'suddenly', 'saw', 'a', 'golden', 'swan', 'come', 'out', 'of', 'the', 'lake', 'and', 'perch', 'on', 'a', 'stone', 'Oh!', 'A', 'golden', 'swan', 'I', 'must', 'capture', 'it', 'thought', 'the', 'King', 'But', 'as', 'soon', 'as', 'he', 'held', 'his', 'bow', 'up', 'the', 'swan', 'disappeared', 'And', 'the', 'King', 'heard', 'a', 'voice', 'I', 'am', 'the', 'Golden', 'Swan', 'If', 'you', 'want', 'to', 'capture', 'me', 'you', 'must', 'come', 'to', 'heaven', 'Surprised', 'the', 'King', 'said', 'Please', 'show', 'me', 'the', 'way', 'to', 'heaven', 'Do', 'good', 'deeds', 'serve', 'your', 'people', 'and', 'the', 'messenger', 'from', 'heaven', 'would', 'come', 'to', 'fetch', 'you', 'to', 'heaven', 'replied', 'the', 'voice', 'The', 'selfish', 'King', 'eager', 'to', 'capture', 'the', 'Swan', 'tried', 'doing', 'some', 'good', 'deeds', 'in', 'his', 'Kingdom', 'Now', 'I', 'suppose', 'a', 'messenger', 'will', 'come', 'to', 'take', 'me', 'to', 'heaven', 'he', 'thought', 'But', 'no', 'messenger', 'came', 'The', 'King', 'then', 'disguised', 'himself', 'and', 'went', 'out', 'into', 'the', 'street', 'There', 'he', 'tried', 'helping', 'an', 'old', 'man', 'But', 'the', 'old', 'man', 'became', 'angry', 'and', 'said', 'You', 'need', 'not', 'try', 'to', 'help', 'I', 'am', 'in', 'this', 'miserable', 'state', 'because', 'of', 'out', 'selfish', 'King', 'He', 'has', 'done', 'nothing', 'for', 'his', 'people', 'Suddenly', 'the', 'King', 'heard', 'the', 'golden', 'swan’s', 'voice', 'Do', 'good', 'deeds', 'and', 'you', 'will', 'come', 'to', 'heaven', 'It', 'dawned', 'on', 'the', 'King', 'that', 'by', 'doing', 'selfish', 'acts', 'he', 'will', 'not', 'go', 'to', 'heaven', 'He', 'realized', 'that', 'his', 'people', 'needed', 'him', 'and', 'carrying', 'out', 'his', 'duties', 'was', 'the', 'only', 'way', 'to', 'heaven', 'After', 'that', 'day', 'he', 'became', 'a', 'responsible', 'King', '']

# %% [markdown]
# #### Exercise 4c: from a list to a vocabulary (a set)
# Please create a set for the words in each text by adding each word to a set. In the end, you should have two variables **vocab_a_story** and **vocab_another_story**, each containing the unique words in each story. Please use the output of Exercise 4b as the input for this exercise.

# %%
vocab_a_story = set()
for word in list_cleaned_story:
    vocab_a_story.update({word})
vocab_a_story
# Out:
# {'',
#  'As',
#  'But',
#  'Do',
#  'Every',
#  'He',
#  'How',
#  'I',
#  'In',
#  'King',
#  'King!',
#  'King’s',
#  'Leave',
#  'O',
#  'One',
#  'Please',
#  'She',
#  'Stop',
#  'The',
#  'They',
#  'This',
#  'We',
#  'You',
#  'a',
#  'added',
#  'all',
#  'am',
#  'and',
#  'angry',
#  'are',
#  'arrogant',
#  'as',
#  'at',
#  'away',
#  'banks',
#  'be',
#  'begged',
#  'beheaded!',
#  'belongs',
#  'bird',
#  'birds',
#  'bring',
#  'brothers',
#  'brought',
#  'built',
#  'but',
#  'by',
#  'came',
#  'can',
#  'collect',
#  'cool',
#  'court',
#  'day',
#  'decide',
#  'decided',
#  'depends',
#  'deposit',
#  'do',
#  'down',
#  'dreaming',
#  'drove',
#  'far',
#  'fear',
#  'feather',
#  'feathers',
#  'feathers?',
#  'fee',
#  'flew',
#  'for',
#  'forever',
#  'further',
#  'gave',
#  'give',
#  'golden',
#  'had',
#  'happily',
#  'have',
#  'having',
#  'hearing',
#  'her',
#  'here',
#  'his',
#  'home',
#  'homeless',
#  'humble',
#  'humiliated',
#  'impolite',
#  'in',
#  'insulted',
#  'kingdom',
#  'lake',
#  'laughing',
#  'leave',
#  'lesson!',
#  'live',
#  'lived',
#  'lives',
#  'make',
#  'many',
#  'me',
#  'months',
#  'most',
#  'my',
#  'near',
#  'never',
#  'no',
#  'not',
#  'noticed',
#  'of',
#  'on',
#  'once',
#  'or',
#  'ordered',
#  'other',
#  'pay',
#  'pleaded',
#  'purchased',
#  'rent',
#  'rent?',
#  'return',
#  'river',
#  'royal',
#  'said',
#  'saw',
#  'seems',
#  'settled',
#  'shelter',
#  'shivered',
#  'shouted',
#  'shouting',
#  'six',
#  'so',
#  'soldiers',
#  'soon',
#  'soothing',
#  'spent',
#  'swans',
#  'teach',
#  'that',
#  'the',
#  'their',
#  'them',
#  'there',
#  'they',
#  'think',
#  'this',
#  'thought',
#  'time',
#  'times',
#  'to',
#  'too',
#  'treasury',
#  'unkind',
#  'upon',
#  'us',
#  'use',
#  'using',
#  'was',
#  'water',
#  'went',
#  'were',
#  'who',
#  'will',
#  'with',
#  'would',
#  'you',
#  'your'}

# %% [markdown]
# do the same for the other text

# %%
vocab_another_story = set()
for word in list_cleaned_another_story:
    vocab_another_story.update({word})
vocab_another_story
# Out:
# {'',
#  'A',
#  'After',
#  'And',
#  'As',
#  'But',
#  'Do',
#  'Golden',
#  'He',
#  'I',
#  'If',
#  'It',
#  'King',
#  'Kingdom',
#  'Long',
#  'Now',
#  'Oh!',
#  'One',
#  'Our',
#  'Please',
#  'Suddenly',
#  'Surprised',
#  'Swan',
#  'The',
#  'There',
#  'To',
#  'You',
#  'a',
#  'acts',
#  'affairs',
#  'ago',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'angry',
#  'as',
#  'became',
#  'because',
#  'bow',
#  'by',
#  'came',
#  'capture',
#  'care',
#  'carried',
#  'carrying',
#  'come',
#  'comforts',
#  'complained',
#  'dawned',
#  'day',
#  'deeds',
#  'disappeared',
#  'disguised',
#  'does',
#  'doing',
#  'done',
#  'drinking',
#  'duties',
#  'eager',
#  'fetch',
#  'for',
#  'forest',
#  'from',
#  'go',
#  'golden',
#  'good',
#  'has',
#  'having',
#  'he',
#  'heard',
#  'heaven',
#  'held',
#  'help',
#  'helping',
#  'him',
#  'himself',
#  'his',
#  'hunt',
#  'ignores',
#  'in',
#  'into',
#  'it',
#  'kingdom',
#  'lake',
#  'lazy',
#  'life',
#  'liked',
#  'lived',
#  'man',
#  'me',
#  'messenger',
#  'miserable',
#  'must',
#  'need',
#  'needed',
#  'needs',
#  'never',
#  'no',
#  'not',
#  'nothing',
#  'of',
#  'old',
#  'on',
#  'only',
#  'our',
#  'out',
#  'people',
#  'perch',
#  'quite',
#  'realized',
#  'relief',
#  'replied',
#  'responsible',
#  'said',
#  'saw',
#  'selfish',
#  'serve',
#  'show',
#  'some',
#  'sometime',
#  'soon',
#  'spotted',
#  'state',
#  'stone',
#  'street',
#  'suddenly',
#  'suppose',
#  'swan',
#  'swan’s',
#  'take',
#  'that',
#  'the',
#  'then',
#  'there',
#  'thirsty',
#  'this',
#  'thought',
#  'time',
#  'to',
#  'tried',
#  'try',
#  'up',
#  'voice',
#  'wandered',
#  'want',
#  'was',
#  'water',
#  'way',
#  'went',
#  'will',
#  'would',
#  'you',
#  'your'}

# %% [markdown]
# ### Exercise 4d: analyzing vocabularies
# Please analyze the vocabularies by using set methods to determine:
# * which words occur in both texts
# * which words only occur in **a_story**
# * which words only occur in **another_story**

# %%
vocab_a_story.intersection(vocab_another_story) #words that occur in both texts
# Out:
# {'',
#  'As',
#  'But',
#  'Do',
#  'He',
#  'I',
#  'King',
#  'One',
#  'Please',
#  'The',
#  'You',
#  'a',
#  'all',
#  'am',
#  'and',
#  'angry',
#  'as',
#  'by',
#  'came',
#  'day',
#  'for',
#  'golden',
#  'having',
#  'his',
#  'in',
#  'kingdom',
#  'lake',
#  'lived',
#  'me',
#  'never',
#  'no',
#  'not',
#  'of',
#  'on',
#  'said',
#  'saw',
#  'soon',
#  'that',
#  'the',
#  'there',
#  'this',
#  'thought',
#  'time',
#  'to',
#  'was',
#  'water',
#  'went',
#  'will',
#  'would',
#  'you',
#  'your'}

# %%
vocab_a_story-vocab_another_story #words only in a story
# Out:
# {'Every',
#  'How',
#  'In',
#  'King!',
#  'King’s',
#  'Leave',
#  'O',
#  'She',
#  'Stop',
#  'They',
#  'This',
#  'We',
#  'added',
#  'are',
#  'arrogant',
#  'at',
#  'away',
#  'banks',
#  'be',
#  'begged',
#  'beheaded!',
#  'belongs',
#  'bird',
#  'birds',
#  'bring',
#  'brothers',
#  'brought',
#  'built',
#  'but',
#  'can',
#  'collect',
#  'cool',
#  'court',
#  'decide',
#  'decided',
#  'depends',
#  'deposit',
#  'do',
#  'down',
#  'dreaming',
#  'drove',
#  'far',
#  'fear',
#  'feather',
#  'feathers',
#  'feathers?',
#  'fee',
#  'flew',
#  'forever',
#  'further',
#  'gave',
#  'give',
#  'had',
#  'happily',
#  'have',
#  'hearing',
#  'her',
#  'here',
#  'home',
#  'homeless',
#  'humble',
#  'humiliated',
#  'impolite',
#  'insulted',
#  'laughing',
#  'leave',
#  'lesson!',
#  'live',
#  'lives',
#  'make',
#  'many',
#  'months',
#  'most',
#  'my',
#  'near',
#  'noticed',
#  'once',
#  'or',
#  'ordered',
#  'other',
#  'pay',
#  'pleaded',
#  'purchased',
#  'rent',
#  'rent?',
#  'return',
#  'river',
#  'royal',
#  'seems',
#  'settled',
#  'shelter',
#  'shivered',
#  'shouted',
#  'shouting',
#  'six',
#  'so',
#  'soldiers',
#  'soothing',
#  'spent',
#  'swans',
#  'teach',
#  'their',
#  'them',
#  'they',
#  'think',
#  'times',
#  'too',
#  'treasury',
#  'unkind',
#  'upon',
#  'us',
#  'use',
#  'using',
#  'were',
#  'who',
#  'with'}

# %%
vocab_another_story-vocab_a_story #words only in another story
# Out:
# {'A',
#  'After',
#  'And',
#  'Golden',
#  'If',
#  'It',
#  'Kingdom',
#  'Long',
#  'Now',
#  'Oh!',
#  'Our',
#  'Suddenly',
#  'Surprised',
#  'Swan',
#  'There',
#  'To',
#  'acts',
#  'affairs',
#  'ago',
#  'also',
#  'an',
#  'became',
#  'because',
#  'bow',
#  'capture',
#  'care',
#  'carried',
#  'carrying',
#  'come',
#  'comforts',
#  'complained',
#  'dawned',
#  'deeds',
#  'disappeared',
#  'disguised',
#  'does',
#  'doing',
#  'done',
#  'drinking',
#  'duties',
#  'eager',
#  'fetch',
#  'forest',
#  'from',
#  'go',
#  'good',
#  'has',
#  'he',
#  'heard',
#  'heaven',
#  'held',
#  'help',
#  'helping',
#  'him',
#  'himself',
#  'hunt',
#  'ignores',
#  'into',
#  'it',
#  'lazy',
#  'life',
#  'liked',
#  'man',
#  'messenger',
#  'miserable',
#  'must',
#  'need',
#  'needed',
#  'needs',
#  'nothing',
#  'old',
#  'only',
#  'our',
#  'out',
#  'people',
#  'perch',
#  'quite',
#  'realized',
#  'relief',
#  'replied',
#  'responsible',
#  'selfish',
#  'serve',
#  'show',
#  'some',
#  'sometime',
#  'spotted',
#  'state',
#  'stone',
#  'street',
#  'suddenly',
#  'suppose',
#  'swan',
#  'swan’s',
#  'take',
#  'then',
#  'thirsty',
#  'tried',
#  'try',
#  'up',
#  'voice',
#  'wandered',
#  'want',
#  'way'}

# %% [markdown]
# ## Exercise 5: counting
# Below you find a list called **words**, which is a list of strings.
#
# a.) Please create a dictionary in which the **key** is the word, and the **value** is the frequency of the word.
#
#
# Exclude all words which meet at least one of the following requirements:
#
#  * end with the letter e
#  * start with the letter t
#  * start with the letter c and end with the letter w (both conditions must be met)
#  * have six or more letters
#
# You are not allowed to use the **collections** module to do this.

# %%
words = ['there',
 'was',
 'a',
 'village',
 'near',
 'a',
 'jungle',
 'the',
 'village',
 'cows',
 'used',
 'to',
 'go',
 'up',
 'to',
 'the',
 'jungle',
 'in',
 'search',
 'of',
 'food.',
 'in',
 'the',
 'forest',
 'there',
 'lived',
 'a',
 'wicked',
 'lion',
 'he',
 'used',
 'to',
 'kill',
 'a',
 'cow',
 'now',
 'and',
 'then',
 'and',
 'eat',
 'her',
 'this',
 'was',
 'happening',
 'for',
 'quite',
 'sometime',
 'the',
 'cows',
 'were',
 'frightened',
 'one',
 'day',
 'all',
 'the',
 'cows',
 'held',
 'a',
 'meeting',
 'an',
 'old',
 'cow',
 'said',
 'listen',
 'everybody',
 'the',
 'lion',
 'eats',
 'one',
 'of',
 'us',
 'only',
 'because',
 'we',
 'go',
 'into',
 'the',
 'jungle',
 'separately',
 'from',
 'now',
 'on',
 'we',
 'will',
 'all',
 'be',
 'together',
 'from',
 'then',
 'on',
 'all',
 'the',
 'cows',
 'went',
 'into',
 'the',
 'jungle',
 'in',
 'a',
 'herd',
 'when',
 'they',
 'heard',
 'or',
 'saw',
 'the',
 'lion',
 'all',
 'of',
 'them',
 'unitedly',
 'moo',
 'and',
 'chased',
 'him',
 'away',
 'moral',
 'divided',
 'we',
 'fall',
 'united',
 'we',
 'stand']

# %%
dictionary = {}
for word in set(words):
    if not (word[-1] == "e" or word[0] == "t" or (word[0] == "c" and word[-1] == "w") or len(word)>5):
            dictionary[word] = words.count(word)
dictionary
# Out:
# {'heard': 1,
#  'or': 1,
#  'stand': 1,
#  'eats': 1,
#  'a': 6,
#  'when': 1,
#  'eat': 1,
#  'will': 1,
#  'was': 2,
#  'all': 4,
#  'moo': 1,
#  'of': 3,
#  'near': 1,
#  'said': 1,
#  'lived': 1,
#  'lion': 3,
#  'in': 3,
#  'only': 1,
#  'into': 2,
#  'moral': 1,
#  'and': 3,
#  'go': 2,
#  'day': 1,
#  'fall': 1,
#  'on': 2,
#  'saw': 1,
#  'used': 2,
#  'went': 1,
#  'us': 1,
#  'herd': 1,
#  'now': 2,
#  'her': 1,
#  'old': 1,
#  'for': 1,
#  'cows': 4,
#  'away': 1,
#  'kill': 1,
#  'from': 2,
#  'food.': 1,
#  'up': 1,
#  'held': 1,
#  'an': 1,
#  'him': 1}

# %% [markdown]
# b.) Analyze your dicitionary by printing:
# * how many keys it has
# * what the highest word frequency is
# * the sum of all values.

# %%
len(dictionary) #number of keys in the dictionary
# Out:
# 43

# %%
max(dictionary.values()), max(dictionary, key=dictionary.get) #highest word freq
# Out:
# (6, 'a')

# %%
sum(dictionary.values()) #sum of all values
# Out:
# 69

# %% [markdown]
# c.) In addition, print the frequencies of the following words using your dictionary (if the word does not occur in the dictionary, print 'WORD does not occur')
# * up
# * near
# * together
# * lion
# * cow

# %%
for word in ['up', 'near' , 'together', 'lion', 'cow']:
    if dictionary.get(word):
        print(f"{word} occurs {dictionary.get(word)} times in our dictionary\n")
    else:
        print(f"{word} does not occur\n")
# Out:
# up occurs 1 times in our dictionary
#
# near occurs 1 times in our dictionary
#
# together does not occur
#
# lion occurs 3 times in our dictionary
#
# cow does not occur

# %% [markdown]
# ## Exercise 6: Functions

# %% [markdown]
# #### Exercise 6a: the beersong
# Please write a function that prints the beersong when it is called.
# The function:
# * is called `print_beersong`
# * has one positional parameter `start_number` (this is 99 in the original song)
# * prints the beer song

# %%
start_number = 99
initial = start_number
def print_beersong(start_number):
    while start_number>= 0:
        if start_number==1:
            current_string = 'bottle'
            next_string = 'bottles'
        elif start_number==2:
            current_string = 'bottles'
            next_string = 'bottle'
        else:
            current_string = 'bottles'
            next_string = 'bottles'

        if start_number>0:
            print(f"{start_number} {current_string} of beer on the wall,")
            print(f"{start_number} {current_string} of beer.")
            print("Take one down, pass it around,")
            print(f"{start_number-1} {next_string} of beer on the wall.\n")
            if start_number==1:
                print(f"{start_number} {current_string} of beer on the wall,")
                print(f"{start_number} {current_string} of beer.")
                print("Take one down, pass it around,")
                print(f"No more {next_string} of beer on the wall.\n")     

        if start_number==0:
            print("No more bottles of beer on the wall,")
            print("No more bottles of beer.")
            print("Go to the store and buy some more,")
            print(f"{initial} bottles of beer on the wall.")
        start_number -= 1
              
print_beersong(start_number)
# Out:
# 99 bottles of beer on the wall,
# 99 bottles of beer.
# Take one down, pass it around,
# 98 bottles of beer on the wall.
#
# 98 bottles of beer on the wall,
# 98 bottles of beer.
# Take one down, pass it around,
# 97 bottles of beer on the wall.
#
# 97 bottles of beer on the wall,
# 97 bottles of beer.
# Take one down, pass it around,
# 96 bottles of beer on the wall.
#
# 96 bottles of beer on the wall,
# 96 bottles of beer.
# Take one down, pass it around,
# 95 bottles of beer on the wall.
#
# 95 bottles of beer on the wall,
# 95 bottles of beer.
# Take one down, pass it around,
# 94 bottles of beer on the wall.
#
# 94 bottles of beer on the wall,
# 94 bottles of beer.
# Take one down, pass it around,
# 93 bottles of beer on the wall.
#
# 93 bottles of beer on the wall,
# 93 bottles of beer.
# Take one down, pass it around,
# 92 bottles of beer on the wall.
#
# 92 bottles of beer on the wall,
# 92 bottles of beer.
# Take one down, pass it around,
# 91 bottles of beer on the wall.
#
# 91 bottles of beer on the wall,
# 91 bottles of beer.
# Take one down, pass it around,
# 90 bottles of beer on the wall.
#
# 90 bottles of beer on the wall,
# 90 bottles of beer.
# Take one down, pass it around,
# 89 bottles of beer on the wall.
#
# 89 bottles of beer on the wall,
# 89 bottles of beer.
# Take one down, pass it around,
# 88 bottles of beer on the wall.
#
# 88 bottles of beer on the wall,
# 88 bottles of beer.
# Take one down, pass it around,
# 87 bottles of beer on the wall.
#
# 87 bottles of beer on the wall,
# 87 bottles of beer.
# Take one down, pass it around,
# 86 bottles of beer on the wall.
#
# 86 bottles of beer on the wall,
# 86 bottles of beer.
# Take one down, pass it around,
# 85 bottles of beer on the wall.
#
# 85 bottles of beer on the wall,
# 85 bottles of beer.
# Take one down, pass it around,
# 84 bottles of beer on the wall.
#
# 84 bottles of beer on the wall,
# 84 bottles of beer.
# Take one down, pass it around,
# 83 bottles of beer on the wall.
#
# 83 bottles of beer on the wall,
# 83 bottles of beer.
# Take one down, pass it around,
# 82 bottles of beer on the wall.
#
# 82 bottles of beer on the wall,
# 82 bottles of beer.
# Take one down, pass it around,
# 81 bottles of beer on the wall.
#
# 81 bottles of beer on the wall,
# 81 bottles of beer.
# Take one down, pass it around,
# 80 bottles of beer on the wall.
#
# 80 bottles of beer on the wall,
# 80 bottles of beer.
# Take one down, pass it around,
# 79 bottles of beer on the wall.
#
# 79 bottles of beer on the wall,
# 79 bottles of beer.
# Take one down, pass it around,
# 78 bottles of beer on the wall.
#
# 78 bottles of beer on the wall,
# 78 bottles of beer.
# Take one down, pass it around,
# 77 bottles of beer on the wall.
#
# 77 bottles of beer on the wall,
# 77 bottles of beer.
# Take one down, pass it around,
# 76 bottles of beer on the wall.
#
# 76 bottles of beer on the wall,
# 76 bottles of beer.
# Take one down, pass it around,
# 75 bottles of beer on the wall.
#
# 75 bottles of beer on the wall,
# 75 bottles of beer.
# Take one down, pass it around,
# 74 bottles of beer on the wall.
#
# 74 bottles of beer on the wall,
# 74 bottles of beer.
# Take one down, pass it around,
# 73 bottles of beer on the wall.
#
# 73 bottles of beer on the wall,
# 73 bottles of beer.
# Take one down, pass it around,
# 72 bottles of beer on the wall.
#
# 72 bottles of beer on the wall,
# 72 bottles of beer.
# Take one down, pass it around,
# 71 bottles of beer on the wall.
#
# 71 bottles of beer on the wall,
# 71 bottles of beer.
# Take one down, pass it around,
# 70 bottles of beer on the wall.
#
# 70 bottles of beer on the wall,
# 70 bottles of beer.
# Take one down, pass it around,
# 69 bottles of beer on the wall.
#
# 69 bottles of beer on the wall,
# 69 bottles of beer.
# Take one down, pass it around,
# 68 bottles of beer on the wall.
#
# 68 bottles of beer on the wall,
# 68 bottles of beer.
# Take one down, pass it around,
# 67 bottles of beer on the wall.
#
# 67 bottles of beer on the wall,
# 67 bottles of beer.
# Take one down, pass it around,
# 66 bottles of beer on the wall.
#
# 66 bottles of beer on the wall,
# 66 bottles of beer.
# Take one down, pass it around,
# 65 bottles of beer on the wall.
#
# 65 bottles of beer on the wall,
# 65 bottles of beer.
# Take one down, pass it around,
# 64 bottles of beer on the wall.
#
# 64 bottles of beer on the wall,
# 64 bottles of beer.
# Take one down, pass it around,
# 63 bottles of beer on the wall.
#
# 63 bottles of beer on the wall,
# 63 bottles of beer.
# Take one down, pass it around,
# 62 bottles of beer on the wall.
#
# 62 bottles of beer on the wall,
# 62 bottles of beer.
# Take one down, pass it around,
# 61 bottles of beer on the wall.
#
# 61 bottles of beer on the wall,
# 61 bottles of beer.
# Take one down, pass it around,
# 60 bottles of beer on the wall.
#
# 60 bottles of beer on the wall,
# 60 bottles of beer.
# Take one down, pass it around,
# 59 bottles of beer on the wall.
#
# 59 bottles of beer on the wall,
# 59 bottles of beer.
# Take one down, pass it around,
# 58 bottles of beer on the wall.
#
# 58 bottles of beer on the wall,
# 58 bottles of beer.
# Take one down, pass it around,
# 57 bottles of beer on the wall.
#
# 57 bottles of beer on the wall,
# 57 bottles of beer.
# Take one down, pass it around,
# 56 bottles of beer on the wall.
#
# 56 bottles of beer on the wall,
# 56 bottles of beer.
# Take one down, pass it around,
# 55 bottles of beer on the wall.
#
# 55 bottles of beer on the wall,
# 55 bottles of beer.
# Take one down, pass it around,
# 54 bottles of beer on the wall.
#
# 54 bottles of beer on the wall,
# 54 bottles of beer.
# Take one down, pass it around,
# 53 bottles of beer on the wall.
#
# 53 bottles of beer on the wall,
# 53 bottles of beer.
# Take one down, pass it around,
# 52 bottles of beer on the wall.
#
# 52 bottles of beer on the wall,
# 52 bottles of beer.
# Take one down, pass it around,
# 51 bottles of beer on the wall.
#
# 51 bottles of beer on the wall,
# 51 bottles of beer.
# Take one down, pass it around,
# 50 bottles of beer on the wall.
#
# 50 bottles of beer on the wall,
# 50 bottles of beer.
# Take one down, pass it around,
# 49 bottles of beer on the wall.
#
# 49 bottles of beer on the wall,
# 49 bottles of beer.
# Take one down, pass it around,
# 48 bottles of beer on the wall.
#
# 48 bottles of beer on the wall,
# 48 bottles of beer.
# Take one down, pass it around,
# 47 bottles of beer on the wall.
#
# 47 bottles of beer on the wall,
# 47 bottles of beer.
# Take one down, pass it around,
# 46 bottles of beer on the wall.
#
# 46 bottles of beer on the wall,
# 46 bottles of beer.
# Take one down, pass it around,
# 45 bottles of beer on the wall.
#
# 45 bottles of beer on the wall,
# 45 bottles of beer.
# Take one down, pass it around,
# 44 bottles of beer on the wall.
#
# 44 bottles of beer on the wall,
# 44 bottles of beer.
# Take one down, pass it around,
# 43 bottles of beer on the wall.
#
# 43 bottles of beer on the wall,
# 43 bottles of beer.
# Take one down, pass it around,
# 42 bottles of beer on the wall.
#
# 42 bottles of beer on the wall,
# 42 bottles of beer.
# Take one down, pass it around,
# 41 bottles of beer on the wall.
#
# 41 bottles of beer on the wall,
# 41 bottles of beer.
# Take one down, pass it around,
# 40 bottles of beer on the wall.
#
# 40 bottles of beer on the wall,
# 40 bottles of beer.
# Take one down, pass it around,
# 39 bottles of beer on the wall.
#
# 39 bottles of beer on the wall,
# 39 bottles of beer.
# Take one down, pass it around,
# 38 bottles of beer on the wall.
#
# 38 bottles of beer on the wall,
# 38 bottles of beer.
# Take one down, pass it around,
# 37 bottles of beer on the wall.
#
# 37 bottles of beer on the wall,
# 37 bottles of beer.
# Take one down, pass it around,
# 36 bottles of beer on the wall.
#
# 36 bottles of beer on the wall,
# 36 bottles of beer.
# Take one down, pass it around,
# 35 bottles of beer on the wall.
#
# 35 bottles of beer on the wall,
# 35 bottles of beer.
# Take one down, pass it around,
# 34 bottles of beer on the wall.
#
# 34 bottles of beer on the wall,
# 34 bottles of beer.
# Take one down, pass it around,
# 33 bottles of beer on the wall.
#
# 33 bottles of beer on the wall,
# 33 bottles of beer.
# Take one down, pass it around,
# 32 bottles of beer on the wall.
#
# 32 bottles of beer on the wall,
# 32 bottles of beer.
# Take one down, pass it around,
# 31 bottles of beer on the wall.
#
# 31 bottles of beer on the wall,
# 31 bottles of beer.
# Take one down, pass it around,
# 30 bottles of beer on the wall.
#
# 30 bottles of beer on the wall,
# 30 bottles of beer.
# Take one down, pass it around,
# 29 bottles of beer on the wall.
#
# 29 bottles of beer on the wall,
# 29 bottles of beer.
# Take one down, pass it around,
# 28 bottles of beer on the wall.
#
# 28 bottles of beer on the wall,
# 28 bottles of beer.
# Take one down, pass it around,
# 27 bottles of beer on the wall.
#
# 27 bottles of beer on the wall,
# 27 bottles of beer.
# Take one down, pass it around,
# 26 bottles of beer on the wall.
#
# 26 bottles of beer on the wall,
# 26 bottles of beer.
# Take one down, pass it around,
# 25 bottles of beer on the wall.
#
# 25 bottles of beer on the wall,
# 25 bottles of beer.
# Take one down, pass it around,
# 24 bottles of beer on the wall.
#
# 24 bottles of beer on the wall,
# 24 bottles of beer.
# Take one down, pass it around,
# 23 bottles of beer on the wall.
#
# 23 bottles of beer on the wall,
# 23 bottles of beer.
# Take one down, pass it around,
# 22 bottles of beer on the wall.
#
# 22 bottles of beer on the wall,
# 22 bottles of beer.
# Take one down, pass it around,
# 21 bottles of beer on the wall.
#
# 21 bottles of beer on the wall,
# 21 bottles of beer.
# Take one down, pass it around,
# 20 bottles of beer on the wall.
#
# 20 bottles of beer on the wall,
# 20 bottles of beer.
# Take one down, pass it around,
# 19 bottles of beer on the wall.
#
# 19 bottles of beer on the wall,
# 19 bottles of beer.
# Take one down, pass it around,
# 18 bottles of beer on the wall.
#
# 18 bottles of beer on the wall,
# 18 bottles of beer.
# Take one down, pass it around,
# 17 bottles of beer on the wall.
#
# 17 bottles of beer on the wall,
# 17 bottles of beer.
# Take one down, pass it around,
# 16 bottles of beer on the wall.
#
# 16 bottles of beer on the wall,
# 16 bottles of beer.
# Take one down, pass it around,
# 15 bottles of beer on the wall.
#
# 15 bottles of beer on the wall,
# 15 bottles of beer.
# Take one down, pass it around,
# 14 bottles of beer on the wall.
#
# 14 bottles of beer on the wall,
# 14 bottles of beer.
# Take one down, pass it around,
# 13 bottles of beer on the wall.
#
# 13 bottles of beer on the wall,
# 13 bottles of beer.
# Take one down, pass it around,
# 12 bottles of beer on the wall.
#
# 12 bottles of beer on the wall,
# 12 bottles of beer.
# Take one down, pass it around,
# 11 bottles of beer on the wall.
#
# 11 bottles of beer on the wall,
# 11 bottles of beer.
# Take one down, pass it around,
# 10 bottles of beer on the wall.
#
# 10 bottles of beer on the wall,
# 10 bottles of beer.
# Take one down, pass it around,
# 9 bottles of beer on the wall.
#
# 9 bottles of beer on the wall,
# 9 bottles of beer.
# Take one down, pass it around,
# 8 bottles of beer on the wall.
#
# 8 bottles of beer on the wall,
# 8 bottles of beer.
# Take one down, pass it around,
# 7 bottles of beer on the wall.
#
# 7 bottles of beer on the wall,
# 7 bottles of beer.
# Take one down, pass it around,
# 6 bottles of beer on the wall.
#
# 6 bottles of beer on the wall,
# 6 bottles of beer.
# Take one down, pass it around,
# 5 bottles of beer on the wall.
#
# 5 bottles of beer on the wall,
# 5 bottles of beer.
# Take one down, pass it around,
# 4 bottles of beer on the wall.
#
# 4 bottles of beer on the wall,
# 4 bottles of beer.
# Take one down, pass it around,
# 3 bottles of beer on the wall.
#
# 3 bottles of beer on the wall,
# 3 bottles of beer.
# Take one down, pass it around,
# 2 bottles of beer on the wall.
#
# 2 bottles of beer on the wall,
# 2 bottles of beer.
# Take one down, pass it around,
# 1 bottle of beer on the wall.
#
# 1 bottle of beer on the wall,
# 1 bottle of beer.
# Take one down, pass it around,
# 0 bottles of beer on the wall.
#
# 1 bottle of beer on the wall,
# 1 bottle of beer.
# Take one down, pass it around,
# No more bottles of beer on the wall.
#
# No more bottles of beer on the wall,
# No more bottles of beer.
# Go to the store and buy some more,
# 99 bottles of beer on the wall.

# %% [markdown]
# #### Exercise 6b: the whatever can be in a bottle song
# There are other liquids than beer than can be placed in a bottle, e.g., *99 bottles of water on the wall.*.
# Please write a function that prints a variation of the beersong when it is called. All occurrences of **beer** will be replaced by what the user provides as an argument, e.g., *water*.
#
# The function:
# * is called `print_liquids`
# * has one positional parameter: `start_number` (this is **99** in the original song)
# * has one keyword parameter: `liquid` (set the default value to **beer**)
# * prints a liquids song

# %%
liquid = str(input("enter a liquid \n"))
start_number = 99
initial = start_number
def print_beersong(start_number):
    while start_number>= 0:
        if start_number==1:
            current_string = 'bottle'
            next_string = 'bottles'
        elif start_number==2:
            current_string = 'bottles'
            next_string = 'bottle'
        else:
            current_string = 'bottles'
            next_string = 'bottles'

        if start_number>0:
            print(f"{start_number} {current_string} of {liquid} on the wall,")
            print(f"{start_number} {current_string} of {liquid}.")
            print("Take one down, pass it around,")
            print(f"{start_number-1} {next_string} of {liquid} on the wall.\n")
            if start_number==1:
                print(f"{start_number} {current_string} of {liquid} on the wall,")
                print(f"{start_number} {current_string} of {liquid}.")
                print("Take one down, pass it around,")
                print(f"No more {next_string} of beer on the wall.\n")     

        if start_number==0:
            print(f"No more bottles of {liquid} on the wall,")
            print(f"No more bottles of {liquid}.")
            print("Go to the store and buy some more,")
            print(f"{initial} bottles of {liquid} on the wall.")
        start_number -= 1
              
print_beersong(start_number)
# Out:
# enter a liquid
# oil
# 99 bottles of oil on the wall,
# 99 bottles of oil.
# Take one down, pass it around,
# 98 bottles of oil on the wall.
#
# 98 bottles of oil on the wall,
# 98 bottles of oil.
# Take one down, pass it around,
# 97 bottles of oil on the wall.
#
# 97 bottles of oil on the wall,
# 97 bottles of oil.
# Take one down, pass it around,
# 96 bottles of oil on the wall.
#
# 96 bottles of oil on the wall,
# 96 bottles of oil.
# Take one down, pass it around,
# 95 bottles of oil on the wall.
#
# 95 bottles of oil on the wall,
# 95 bottles of oil.
# Take one down, pass it around,
# 94 bottles of oil on the wall.
#
# 94 bottles of oil on the wall,
# 94 bottles of oil.
# Take one down, pass it around,
# 93 bottles of oil on the wall.
#
# 93 bottles of oil on the wall,
# 93 bottles of oil.
# Take one down, pass it around,
# 92 bottles of oil on the wall.
#
# 92 bottles of oil on the wall,
# 92 bottles of oil.
# Take one down, pass it around,
# 91 bottles of oil on the wall.
#
# 91 bottles of oil on the wall,
# 91 bottles of oil.
# Take one down, pass it around,
# 90 bottles of oil on the wall.
#
# 90 bottles of oil on the wall,
# 90 bottles of oil.
# Take one down, pass it around,
# 89 bottles of oil on the wall.
#
# 89 bottles of oil on the wall,
# 89 bottles of oil.
# Take one down, pass it around,
# 88 bottles of oil on the wall.
#
# 88 bottles of oil on the wall,
# 88 bottles of oil.
# Take one down, pass it around,
# 87 bottles of oil on the wall.
#
# 87 bottles of oil on the wall,
# 87 bottles of oil.
# Take one down, pass it around,
# 86 bottles of oil on the wall.
#
# 86 bottles of oil on the wall,
# 86 bottles of oil.
# Take one down, pass it around,
# 85 bottles of oil on the wall.
#
# 85 bottles of oil on the wall,
# 85 bottles of oil.
# Take one down, pass it around,
# 84 bottles of oil on the wall.
#
# 84 bottles of oil on the wall,
# 84 bottles of oil.
# Take one down, pass it around,
# 83 bottles of oil on the wall.
#
# 83 bottles of oil on the wall,
# 83 bottles of oil.
# Take one down, pass it around,
# 82 bottles of oil on the wall.
#
# 82 bottles of oil on the wall,
# 82 bottles of oil.
# Take one down, pass it around,
# 81 bottles of oil on the wall.
#
# 81 bottles of oil on the wall,
# 81 bottles of oil.
# Take one down, pass it around,
# 80 bottles of oil on the wall.
#
# 80 bottles of oil on the wall,
# 80 bottles of oil.
# Take one down, pass it around,
# 79 bottles of oil on the wall.
#
# 79 bottles of oil on the wall,
# 79 bottles of oil.
# Take one down, pass it around,
# 78 bottles of oil on the wall.
#
# 78 bottles of oil on the wall,
# 78 bottles of oil.
# Take one down, pass it around,
# 77 bottles of oil on the wall.
#
# 77 bottles of oil on the wall,
# 77 bottles of oil.
# Take one down, pass it around,
# 76 bottles of oil on the wall.
#
# 76 bottles of oil on the wall,
# 76 bottles of oil.
# Take one down, pass it around,
# 75 bottles of oil on the wall.
#
# 75 bottles of oil on the wall,
# 75 bottles of oil.
# Take one down, pass it around,
# 74 bottles of oil on the wall.
#
# 74 bottles of oil on the wall,
# 74 bottles of oil.
# Take one down, pass it around,
# 73 bottles of oil on the wall.
#
# 73 bottles of oil on the wall,
# 73 bottles of oil.
# Take one down, pass it around,
# 72 bottles of oil on the wall.
#
# 72 bottles of oil on the wall,
# 72 bottles of oil.
# Take one down, pass it around,
# 71 bottles of oil on the wall.
#
# 71 bottles of oil on the wall,
# 71 bottles of oil.
# Take one down, pass it around,
# 70 bottles of oil on the wall.
#
# 70 bottles of oil on the wall,
# 70 bottles of oil.
# Take one down, pass it around,
# 69 bottles of oil on the wall.
#
# 69 bottles of oil on the wall,
# 69 bottles of oil.
# Take one down, pass it around,
# 68 bottles of oil on the wall.
#
# 68 bottles of oil on the wall,
# 68 bottles of oil.
# Take one down, pass it around,
# 67 bottles of oil on the wall.
#
# 67 bottles of oil on the wall,
# 67 bottles of oil.
# Take one down, pass it around,
# 66 bottles of oil on the wall.
#
# 66 bottles of oil on the wall,
# 66 bottles of oil.
# Take one down, pass it around,
# 65 bottles of oil on the wall.
#
# 65 bottles of oil on the wall,
# 65 bottles of oil.
# Take one down, pass it around,
# 64 bottles of oil on the wall.
#
# 64 bottles of oil on the wall,
# 64 bottles of oil.
# Take one down, pass it around,
# 63 bottles of oil on the wall.
#
# 63 bottles of oil on the wall,
# 63 bottles of oil.
# Take one down, pass it around,
# 62 bottles of oil on the wall.
#
# 62 bottles of oil on the wall,
# 62 bottles of oil.
# Take one down, pass it around,
# 61 bottles of oil on the wall.
#
# 61 bottles of oil on the wall,
# 61 bottles of oil.
# Take one down, pass it around,
# 60 bottles of oil on the wall.
#
# 60 bottles of oil on the wall,
# 60 bottles of oil.
# Take one down, pass it around,
# 59 bottles of oil on the wall.
#
# 59 bottles of oil on the wall,
# 59 bottles of oil.
# Take one down, pass it around,
# 58 bottles of oil on the wall.
#
# 58 bottles of oil on the wall,
# 58 bottles of oil.
# Take one down, pass it around,
# 57 bottles of oil on the wall.
#
# 57 bottles of oil on the wall,
# 57 bottles of oil.
# Take one down, pass it around,
# 56 bottles of oil on the wall.
#
# 56 bottles of oil on the wall,
# 56 bottles of oil.
# Take one down, pass it around,
# 55 bottles of oil on the wall.
#
# 55 bottles of oil on the wall,
# 55 bottles of oil.
# Take one down, pass it around,
# 54 bottles of oil on the wall.
#
# 54 bottles of oil on the wall,
# 54 bottles of oil.
# Take one down, pass it around,
# 53 bottles of oil on the wall.
#
# 53 bottles of oil on the wall,
# 53 bottles of oil.
# Take one down, pass it around,
# 52 bottles of oil on the wall.
#
# 52 bottles of oil on the wall,
# 52 bottles of oil.
# Take one down, pass it around,
# 51 bottles of oil on the wall.
#
# 51 bottles of oil on the wall,
# 51 bottles of oil.
# Take one down, pass it around,
# 50 bottles of oil on the wall.
#
# 50 bottles of oil on the wall,
# 50 bottles of oil.
# Take one down, pass it around,
# 49 bottles of oil on the wall.
#
# 49 bottles of oil on the wall,
# 49 bottles of oil.
# Take one down, pass it around,
# 48 bottles of oil on the wall.
#
# 48 bottles of oil on the wall,
# 48 bottles of oil.
# Take one down, pass it around,
# 47 bottles of oil on the wall.
#
# 47 bottles of oil on the wall,
# 47 bottles of oil.
# Take one down, pass it around,
# 46 bottles of oil on the wall.
#
# 46 bottles of oil on the wall,
# 46 bottles of oil.
# Take one down, pass it around,
# 45 bottles of oil on the wall.
#
# 45 bottles of oil on the wall,
# 45 bottles of oil.
# Take one down, pass it around,
# 44 bottles of oil on the wall.
#
# 44 bottles of oil on the wall,
# 44 bottles of oil.
# Take one down, pass it around,
# 43 bottles of oil on the wall.
#
# 43 bottles of oil on the wall,
# 43 bottles of oil.
# Take one down, pass it around,
# 42 bottles of oil on the wall.
#
# 42 bottles of oil on the wall,
# 42 bottles of oil.
# Take one down, pass it around,
# 41 bottles of oil on the wall.
#
# 41 bottles of oil on the wall,
# 41 bottles of oil.
# Take one down, pass it around,
# 40 bottles of oil on the wall.
#
# 40 bottles of oil on the wall,
# 40 bottles of oil.
# Take one down, pass it around,
# 39 bottles of oil on the wall.
#
# 39 bottles of oil on the wall,
# 39 bottles of oil.
# Take one down, pass it around,
# 38 bottles of oil on the wall.
#
# 38 bottles of oil on the wall,
# 38 bottles of oil.
# Take one down, pass it around,
# 37 bottles of oil on the wall.
#
# 37 bottles of oil on the wall,
# 37 bottles of oil.
# Take one down, pass it around,
# 36 bottles of oil on the wall.
#
# 36 bottles of oil on the wall,
# 36 bottles of oil.
# Take one down, pass it around,
# 35 bottles of oil on the wall.
#
# 35 bottles of oil on the wall,
# 35 bottles of oil.
# Take one down, pass it around,
# 34 bottles of oil on the wall.
#
# 34 bottles of oil on the wall,
# 34 bottles of oil.
# Take one down, pass it around,
# 33 bottles of oil on the wall.
#
# 33 bottles of oil on the wall,
# 33 bottles of oil.
# Take one down, pass it around,
# 32 bottles of oil on the wall.
#
# 32 bottles of oil on the wall,
# 32 bottles of oil.
# Take one down, pass it around,
# 31 bottles of oil on the wall.
#
# 31 bottles of oil on the wall,
# 31 bottles of oil.
# Take one down, pass it around,
# 30 bottles of oil on the wall.
#
# 30 bottles of oil on the wall,
# 30 bottles of oil.
# Take one down, pass it around,
# 29 bottles of oil on the wall.
#
# 29 bottles of oil on the wall,
# 29 bottles of oil.
# Take one down, pass it around,
# 28 bottles of oil on the wall.
#
# 28 bottles of oil on the wall,
# 28 bottles of oil.
# Take one down, pass it around,
# 27 bottles of oil on the wall.
#
# 27 bottles of oil on the wall,
# 27 bottles of oil.
# Take one down, pass it around,
# 26 bottles of oil on the wall.
#
# 26 bottles of oil on the wall,
# 26 bottles of oil.
# Take one down, pass it around,
# 25 bottles of oil on the wall.
#
# 25 bottles of oil on the wall,
# 25 bottles of oil.
# Take one down, pass it around,
# 24 bottles of oil on the wall.
#
# 24 bottles of oil on the wall,
# 24 bottles of oil.
# Take one down, pass it around,
# 23 bottles of oil on the wall.
#
# 23 bottles of oil on the wall,
# 23 bottles of oil.
# Take one down, pass it around,
# 22 bottles of oil on the wall.
#
# 22 bottles of oil on the wall,
# 22 bottles of oil.
# Take one down, pass it around,
# 21 bottles of oil on the wall.
#
# 21 bottles of oil on the wall,
# 21 bottles of oil.
# Take one down, pass it around,
# 20 bottles of oil on the wall.
#
# 20 bottles of oil on the wall,
# 20 bottles of oil.
# Take one down, pass it around,
# 19 bottles of oil on the wall.
#
# 19 bottles of oil on the wall,
# 19 bottles of oil.
# Take one down, pass it around,
# 18 bottles of oil on the wall.
#
# 18 bottles of oil on the wall,
# 18 bottles of oil.
# Take one down, pass it around,
# 17 bottles of oil on the wall.
#
# 17 bottles of oil on the wall,
# 17 bottles of oil.
# Take one down, pass it around,
# 16 bottles of oil on the wall.
#
# 16 bottles of oil on the wall,
# 16 bottles of oil.
# Take one down, pass it around,
# 15 bottles of oil on the wall.
#
# 15 bottles of oil on the wall,
# 15 bottles of oil.
# Take one down, pass it around,
# 14 bottles of oil on the wall.
#
# 14 bottles of oil on the wall,
# 14 bottles of oil.
# Take one down, pass it around,
# 13 bottles of oil on the wall.
#
# 13 bottles of oil on the wall,
# 13 bottles of oil.
# Take one down, pass it around,
# 12 bottles of oil on the wall.
#
# 12 bottles of oil on the wall,
# 12 bottles of oil.
# Take one down, pass it around,
# 11 bottles of oil on the wall.
#
# 11 bottles of oil on the wall,
# 11 bottles of oil.
# Take one down, pass it around,
# 10 bottles of oil on the wall.
#
# 10 bottles of oil on the wall,
# 10 bottles of oil.
# Take one down, pass it around,
# 9 bottles of oil on the wall.
#
# 9 bottles of oil on the wall,
# 9 bottles of oil.
# Take one down, pass it around,
# 8 bottles of oil on the wall.
#
# 8 bottles of oil on the wall,
# 8 bottles of oil.
# Take one down, pass it around,
# 7 bottles of oil on the wall.
#
# 7 bottles of oil on the wall,
# 7 bottles of oil.
# Take one down, pass it around,
# 6 bottles of oil on the wall.
#
# 6 bottles of oil on the wall,
# 6 bottles of oil.
# Take one down, pass it around,
# 5 bottles of oil on the wall.
#
# 5 bottles of oil on the wall,
# 5 bottles of oil.
# Take one down, pass it around,
# 4 bottles of oil on the wall.
#
# 4 bottles of oil on the wall,
# 4 bottles of oil.
# Take one down, pass it around,
# 3 bottles of oil on the wall.
#
# 3 bottles of oil on the wall,
# 3 bottles of oil.
# Take one down, pass it around,
# 2 bottles of oil on the wall.
#
# 2 bottles of oil on the wall,
# 2 bottles of oil.
# Take one down, pass it around,
# 1 bottle of oil on the wall.
#
# 1 bottle of oil on the wall,
# 1 bottle of oil.
# Take one down, pass it around,
# 0 bottles of oil on the wall.
#
# 1 bottle of oil on the wall,
# 1 bottle of oil.
# Take one down, pass it around,
# No more bottles of beer on the wall.
#
# No more bottles of oil on the wall,
# No more bottles of oil.
# Go to the store and buy some more,
# 99 bottles of oil on the wall.

# %% [markdown]
# #### Exercise 6c: preprocessing text
# Please write the answer to Exercise 4a as a function. The function replaces the following characters by empty spaces in a text:
# * newlines: '\n'
# * commas: ','
# * dots: '.'
# * quotes: '"'
#
# The function is:
# * is called `clean_text`
# * has one positional parameter `text`
# * return a string, e.g., the cleaned text

# %%
def clean_text(text):
    cleaned_text = text.replace('\n','').replace(',','').replace('.','').replace('"','')
    return cleaned_text
clean_text(a_story)
# Out:
# 'In a far away kingdom there was a river This river was home to many golden swans The swans spent most of their time on the banks of the river Every six months the swans would leave a golden feather as a fee for using the lake The soldiers of the kingdom would collect the feathers and deposit them in the royal treasury One day a homeless bird saw the river The water in this river seems so cool and soothing I will make my home here thought the bird As soon as the bird settled down near the river the golden swans noticed her They came shouting This river belongs to us We pay a golden feather to the King to use this river You can not live here I am homeless brothers I too will pay the rent Please give me shelter the bird pleaded How will you pay the rent? You do not have golden feathers said the swans laughing They further added Stop dreaming and leave once The humble bird pleaded many times But the arrogant swans drove the bird away I will teach them a lesson! decided the humiliated bird She went to the King and said O King! The swans in your river are impolite and unkind I begged for shelter but they said that they had purchased the river with golden feathers The King was angry with the arrogant swans for having insulted the homeless bird He ordered his soldiers to bring the arrogant swans to his court In no time all the golden swans were brought to the King’s court Do you think the royal treasury depends upon your golden feathers? You can not decide who lives by the river Leave the river at once or you all will be beheaded! shouted the King The swans shivered with fear on hearing the King They flew away never to return The bird built her home near the river and lived there happily forever The bird gave shelter to all other birds in the river '

# %% [markdown]
# #### Exercise 6d: preprocessing text in a more general way
# Please write a function that replaces all characters that the user provides by empty spaces.
#
# The function is:
# * is called `clean_text_general`
# * has one positional parameter `text`
# * has one keyword parameter `chars_to_remove`, which is a set (set the default to {'\n', ',', '.', '"'})
# * return a string, e.g., the cleaned text
#
# When the user provides a different value to `chars_to_remove`, e.g., {'a'}, then only those characters should be replaced by empty spaces in the text.

# %%
def clean_text_general(text, chars_to_remove={'\n', ',', '.', '"'}):
    for char in chars_to_remove:
        text = text.replace(char,'')
    return text

# %% [markdown]
# Please store this function in a file called **assignment2_utils.py**. Please import the function and call it in this notebook.

# %%
from assignment2_utils import clean_text_general
clean_text_general(a_story)
# Out:
# 'In a far away kingdom there was a river This river was home to many golden swans The swans spent most of their time on the banks of the river Every six months the swans would leave a golden feather as a fee for using the lake The soldiers of the kingdom would collect the feathers and deposit them in the royal treasury One day a homeless bird saw the river The water in this river seems so cool and soothing I will make my home here thought the bird As soon as the bird settled down near the river the golden swans noticed her They came shouting This river belongs to us We pay a golden feather to the King to use this river You can not live here I am homeless brothers I too will pay the rent Please give me shelter the bird pleaded How will you pay the rent? You do not have golden feathers said the swans laughing They further added Stop dreaming and leave once The humble bird pleaded many times But the arrogant swans drove the bird away I will teach them a lesson! decided the humiliated bird She went to the King and said O King! The swans in your river are impolite and unkind I begged for shelter but they said that they had purchased the river with golden feathers The King was angry with the arrogant swans for having insulted the homeless bird He ordered his soldiers to bring the arrogant swans to his court In no time all the golden swans were brought to the King’s court Do you think the royal treasury depends upon your golden feathers? You can not decide who lives by the river Leave the river at once or you all will be beheaded! shouted the King The swans shivered with fear on hearing the King They flew away never to return The bird built her home near the river and lived there happily forever The bird gave shelter to all other birds in the river '

# %% [markdown]
# #### Exercise 6e: including and excluding words
# Please write Exercise 5a as a function.
#
# The function:
# * is called `exclude_and_count`
# * has one positional parameter `words`, which is a list of strings.
# * creates a dictionary in which the **key** is a word and the **value** is the frequency of that word.
# * words are excluded if they meet one of the following criteria:
#     * end with the letter e
#     * start with the letter t
#     * start with the letter c and end with the letter w (both conditions must be met)
#     * have six or more letters
# * returns a dictionary in which the **key** is the word and the **value** is the frequency of the word.

# %%
def exclude_and_count(words):
    dictionary = {}
    for word in set(words):
        if not (word[-1] == "e" or word[0] == "t" or (word[0] == "c" and word[-1] == "w") or len(word)>5):
                dictionary[word] = words.count(word)
    return dictionary
print(exclude_and_count(words))
# Out:
# {'used': 2, 'old': 1, 'him': 1, 'saw': 1, 'go': 2, 'of': 3, 'heard': 1, 'for': 1, 'when': 1, 'said': 1, 'eat': 1, 'and': 3, 'a': 6, 'an': 1, 'will': 1, 'all': 4, 'us': 1, 'away': 1, 'lived': 1, 'kill': 1, 'into': 2, 'or': 1, 'was': 2, 'from': 2, 'went': 1, 'stand': 1, 'now': 2, 'lion': 3, 'in': 3, 'eats': 1, 'on': 2, 'only': 1, 'herd': 1, 'day': 1, 'up': 1, 'moral': 1, 'near': 1, 'food.': 1, 'fall': 1, 'her': 1, 'held': 1, 'moo': 1, 'cows': 4}

# %% [markdown]
# ## Exercise 7: Questions about Python
# Please answer the following questions about the Python language. You can give an examples if they help you.

# %% [markdown]
# a. What is the difference between positional parameters and keyword parameters?

# %% [markdown]
# Positional parameters are called by their position in the method where as keyword parameters are be called by their name. Another difference is that positional parameters must be included in the correct order whereas keyword parameters can be included in any order.

# %% [markdown]
# b. What is/are the type/types of containers that you define using curly brackets?

# %% [markdown]
# Dictionaries and sets

# %% [markdown]
# c. When comparing the containers lists and sets, there are three properties that are unique for lists. Please name and explain them.

# %% [markdown]
# 1) Dynamic : Lists are dynamic in nature, i.e., the elements of a list can be changed and/or replaced.
#
# 2) Ordered Collection : Lists are ordered, i.e., the elements of a list have a defined order, and that order will not change.
#
# 3) Index Access : The elements of a list can be accessed by their index.

# %% [markdown]
# d. Explain the difference between **continue** and **break**. You can use an example for this.

# %% [markdown]
# When a continue statement is encountered, the current iteration stops and the next iteration begins whereas when a break statement is encountered, the loop is exited
