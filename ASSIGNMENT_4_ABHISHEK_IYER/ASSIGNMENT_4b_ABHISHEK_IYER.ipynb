# %% [markdown]
# # Assignment 4 MA Part B
#
#
# **Deadline for Assignment 4a+b: Friday October 14, 2022, before 17:00 via Canvas (Assignment 4)**
#
# Tips and clarifications may be posted here: https://docs.google.com/document/d/1sgfaMqJX6raXPiG2Ffk0Hbi1_FPJtbTjd31E9LQBP0E/edit?usp=sharing
#
# **<mark>Tip: This assignment is less guided than the assignments you have worked on so far. Please start early and use the classes (and piazza) to ask for clarification if necessary. </mark>**
#
# ## A corpus of TED talks and their translations
#
# In this assignment, you are going to work with a corpus of transcribed TED talks (English) and their translations into other languages. The resource was developed by
#
#
# The resource is called WIT3 - acronym for Web Inventory of Transcribed and Translated Talks.
#
#
# In part I of the assignment, you are going to analyze the original talks. In part II, you are going to explore the translations.
#
# The learning goals of this assginment are the following:
#
# * Become comfortable with extracting information from xml
# * Learn how to explore a corpus consisting of multiple files
# * Lean how to map information accross mutliple files
# * Take the first steps in indepdently structuring code
#
#
# If you are interesed in learning more about the resource and what it is used for, you can check the following paper:
#
#
# M. Cettolo, C. Girardi, and M. Federico. 2012. WIT3: Web Inventory of Transcribed and Translated Talks.
# In Proc. of EAMT, pp. 261-268, Trento, Italy [pdf].

# %% [markdown]
# # Step 1: Prepare the data and understand the corpus structure
#
# **1.) Download**
#
# Please go to the following url: https://wit3.fbk.eu/home
#
# Download the latest version of the corpus by clicking on "Talks in XML format (109 languages)".
#
# Please the download in the Data directory (`../Data/`). Please create a new folder called `ted-talks` and move the download there. Unpack it (should work by double-clicking on it).
#
#
# The corpus you downloaded contains multiple releases of the data. You data should be at `../Data/ted-talks/XML_releases/`.
#
#
# Please run the following cell below to check.
#
# You should see these files and subdirectories:
#
# * tools.html
# * wit3_xml-20140120.zip
# * wit3.dtd
# * xml/
# * xml-20150616/
# * xml-20140120/
#
# The directories starting with 'xml' contain different versions of the data. We will focus on the most recent version of the data in the directory `xml/`. Feel free to remove the remaining two directories.

# %%
# mac os/linux:
# %ls ../Data/ted-talks/XML_releases
# Out:
# tools.html  wit3.dtd  wit3_xml-20140120.zip  xml/  xml-20140120/  xml-20150616/

# %%
# windows (please adapt if necessary in this and all following cells): 
#%ls ..\Data\ted-talks\XML_releases\
# Out:
# ls: ..Datated-talksXML_releases: No such file or directory

# %% [markdown]
# **2.) Unzipping the xml files**
#
# If you run the next cell, you will see that the xml files are still zipped.
#
# **Mac os/linux**
# To unzip all files at once, navigate to the directory on your command line and run: `unzip "*.zip"`
#
# **Windows**
# On Windowns, the unzip command will not work. Instead, the following command should do the trick (first navigate to the directory on your command line):
#
# `Get-ChildItem 'path to folder' -Filter *.zip | Expand-Archive -DestinationPath 'path to folder' -Force`
#
# Alternatively, you can install a Windows subsystem for Linux (WSL), now you can use an Ubuntu terminal and can thus use all the linux commands on your own windows computer.

# %%
# %ls ../Data/ted-talks/XML_releases/xml
# Out:
# ted_af-20160408.xml          ted_hi-20160408.zip   ted_oc-20160408.xml
# ted_af-20160408.zip          ted_hr-20160408.xml   ted_oc-20160408.zip
# ted_am-20160408.xml          ted_hr-20160408.zip   ted_pa-20160408.xml
# ted_am-20160408.zip          ted_ht-20160408.xml   ted_pa-20160408.zip
# ted_ar-20160408.xml          ted_ht-20160408.zip   ted_pl-20160408.xml
# ted_ar-20160408.zip          ted_hu-20160408.xml   ted_pl-20160408.zip
# ted_arq-20160408.xml         ted_hu-20160408.zip   ted_ps-20160408.xml
# ted_arq-20160408.zip         ted_hup-20160408.xml  ted_ps-20160408.zip
# ted_art-x-bork-20160408.xml  ted_hup-20160408.zip  ted_pt-20160408.xml
# ted_art-x-bork-20160408.zip  ted_hy-20160408.xml   ted_pt-20160408.zip
# ted_as-20160408.xml          ted_hy-20160408.zip   ted_pt-br-20160408.xml
# ted_as-20160408.zip          ted_id-20160408.xml   ted_pt-br-20160408.zip
# ted_ast-20160408.xml         ted_id-20160408.zip   ted_ro-20160408.xml
# ted_ast-20160408.zip         ted_ig-20160408.xml   ted_ro-20160408.zip
# ted_az-20160408.xml          ted_ig-20160408.zip   ted_ru-20160408.xml
# ted_az-20160408.zip          ted_inh-20160408.xml  ted_ru-20160408.zip
# ted_be-20160408.xml          ted_inh-20160408.zip  ted_rup-20160408.xml
# ted_be-20160408.zip          ted_is-20160408.xml   ted_rup-20160408.zip
# ted_bg-20160408.xml          ted_is-20160408.zip   ted_sh-20160408.xml
# ted_bg-20160408.zip          ted_it-20160408.xml   ted_sh-20160408.zip
# ted_bi-20160408.xml          ted_it-20160408.zip   ted_si-20160408.xml
# ted_bi-20160408.zip          ted_ja-20160408.xml   ted_si-20160408.zip
# ted_bn-20160408.xml          ted_ja-20160408.zip   ted_sk-20160408.xml
# ted_bn-20160408.zip          ted_ka-20160408.xml   ted_sk-20160408.zip
# ted_bo-20160408.xml          ted_ka-20160408.zip   ted_sl-20160408.xml
# ted_bo-20160408.zip          ted_kk-20160408.xml   ted_sl-20160408.zip
# ted_bs-20160408.xml          ted_kk-20160408.zip   ted_so-20160408.xml
# ted_bs-20160408.zip          ted_km-20160408.xml   ted_so-20160408.zip
# ted_ca-20160408.xml          ted_km-20160408.zip   ted_sq-20160408.xml
# ted_ca-20160408.zip          ted_kn-20160408.xml   ted_sq-20160408.zip
# ted_ceb-20160408.xml         ted_kn-20160408.zip   ted_sr-20160408.xml
# ted_ceb-20160408.zip         ted_ko-20160408.xml   ted_sr-20160408.zip
# ted_cnh-20160408.xml         ted_ko-20160408.zip   ted_srp-20160408.xml
# ted_cnh-20160408.zip         ted_ku-20160408.xml   ted_srp-20160408.zip
# ted_cs-20160408.xml          ted_ku-20160408.zip   ted_sv-20160408.xml
# ted_cs-20160408.zip          ted_ky-20160408.xml   ted_sv-20160408.zip
# ted_da-20160408.xml          ted_ky-20160408.zip   ted_sw-20160408.xml
# ted_da-20160408.zip          ted_la-20160408.xml   ted_sw-20160408.zip
# ted_de-20160408.xml          ted_la-20160408.zip   ted_szl-20160408.xml
# ted_de-20160408.zip          ted_lb-20160408.xml   ted_szl-20160408.zip
# ted_el-20160408.xml          ted_lb-20160408.zip   ted_ta-20160408.xml
# ted_el-20160408.zip          ted_lo-20160408.xml   ted_ta-20160408.zip
# ted_en-20160408.xml          ted_lo-20160408.zip   ted_te-20160408.xml
# ted_en-20160408.zip          ted_lt-20160408.xml   ted_te-20160408.zip
# ted_eo-20160408.xml          ted_lt-20160408.zip   ted_tg-20160408.xml
# ted_eo-20160408.zip          ted_ltg-20160408.xml  ted_tg-20160408.zip
# ted_es-20160408.xml          ted_ltg-20160408.zip  ted_th-20160408.xml
# ted_es-20160408.zip          ted_lv-20160408.xml   ted_th-20160408.zip
# ted_et-20160408.xml          ted_lv-20160408.zip   ted_tl-20160408.xml
# ted_et-20160408.zip          ted_mg-20160408.xml   ted_tl-20160408.zip
# ted_eu-20160408.xml          ted_mg-20160408.zip   ted_tlh-20160408.xml
# ted_eu-20160408.zip          ted_mk-20160408.xml   ted_tlh-20160408.zip
# ted_fa-20160408.xml          ted_mk-20160408.zip   ted_tr-20160408.xml
# ted_fa-20160408.zip          ted_ml-20160408.xml   ted_tr-20160408.zip
# ted_fi-20160408.xml          ted_ml-20160408.zip   ted_tt-20160408.xml
# ted_fi-20160408.zip          ted_mn-20160408.xml   ted_tt-20160408.zip
# ted_fil-20160408.xml         ted_mn-20160408.zip   ted_ug-20160408.xml
# ted_fil-20160408.zip         ted_mr-20160408.xml   ted_ug-20160408.zip
# ted_fr-20160408.xml          ted_mr-20160408.zip   ted_uk-20160408.xml
# ted_fr-20160408.zip          ted_ms-20160408.xml   ted_uk-20160408.zip
# ted_fr-ca-20160408.xml       ted_ms-20160408.zip   ted_ur-20160408.xml
# ted_fr-ca-20160408.zip       ted_mt-20160408.xml   ted_ur-20160408.zip
# ted_ga-20160408.xml          ted_mt-20160408.zip   ted_uz-20160408.xml
# ted_ga-20160408.zip          ted_my-20160408.xml   ted_uz-20160408.zip
# ted_gl-20160408.xml          ted_my-20160408.zip   ted_vi-20160408.xml
# ted_gl-20160408.zip          ted_nb-20160408.xml   ted_vi-20160408.zip
# ted_gu-20160408.xml          ted_nb-20160408.zip   ted_zh-20160408.xml
# ted_gu-20160408.zip          ted_ne-20160408.xml   ted_zh-20160408.zip
# ted_ha-20160408.xml          ted_ne-20160408.zip   ted_zh-cn-20160408.xml
# ted_ha-20160408.zip          ted_nl-20160408.xml   ted_zh-cn-20160408.zip
# ted_he-20160408.xml          ted_nl-20160408.zip   ted_zh-tw-20160408.xml
# ted_he-20160408.zip          ted_nn-20160408.xml   ted_zh-tw-20160408.zip
# ted_hi-20160408.xml          ted_nn-20160408.zip

# %% [markdown]
# **3.) Understanding the structure of the corpus**
#
#
# List only the xml files in the corpus using the cell below.
#
# You will see that all file names follow the same convention: ted-[language]-[release-date].xml
#
#
# Each file contains all talks translated to the target language (i.e. the language in the file name) from English. Not all talks are translated into all languages. The orginial English talks are in `../Data/ted-talks/XML_releases/xml/ted_en-20160408.xml`.

# %%
# %ls ../Data/ted-talks/XML_releases/xml/*.xml
# Out:
# ../Data/ted-talks/XML_releases/xml/ted_af-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_am-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ar-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_arq-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_art-x-bork-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_as-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ast-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_az-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_be-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_bg-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_bi-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_bn-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_bo-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_bs-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ca-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ceb-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_cnh-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_cs-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_da-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_de-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_el-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_en-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_eo-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_es-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_et-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_eu-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_fa-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_fi-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_fil-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_fr-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_fr-ca-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ga-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_gl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_gu-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ha-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_he-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_hi-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_hr-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ht-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_hu-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_hup-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_hy-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_id-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ig-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_inh-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_is-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_it-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ja-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ka-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_kk-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_km-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_kn-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ko-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ku-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ky-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_la-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_lb-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_lo-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_lt-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ltg-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_lv-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_mg-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_mk-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ml-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_mn-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_mr-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ms-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_mt-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_my-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_nb-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ne-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_nl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_nn-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_oc-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_pa-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_pl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ps-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_pt-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_pt-br-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ro-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ru-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_rup-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sh-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_si-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sk-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_so-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sq-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sr-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_srp-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sv-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_sw-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_szl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ta-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_te-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_tg-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_th-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_tl-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_tlh-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_tr-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_tt-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ug-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_uk-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_ur-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_uz-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_vi-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_zh-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_zh-cn-20160408.xml
# ../Data/ted-talks/XML_releases/xml/ted_zh-tw-20160408.xml

# %% [markdown]
# **4.) Understanding the xml structure and finding translations of the same text**
#
# To extract a translation of a particular text, we have to look into the xml structure of a single file. Open the xml file with the translations into Dutch in an editor (e.g. atom).
#
#
# Try to get a global idea of the structure. The following questions can help to guide you:
#
# (1) How many different talks does the file contain? (Hint: Scroll all the way down.)
#
# (2) Which tags indicate new talks?
#
# (3) Where do you find meta-information about a talk? Where do you find the translated text of the talk? Where do you find the transcription of the video?
#
# (4) Where do you find the identifier of the talk? Hint: look for a tag called 'talkid'. You can use this information to match translations with original talks.
#
# Tip: load one file and explore the information given about one talk using lxml.etree in python. You can use the code below to get started.

# %%
from lxml import etree as et

# %%
test = '../Data/ted-talks/XML_releases/xml/ted_nl-20160408.xml'

# %%
tree = et.parse(test)
root = tree.getroot()

# %%
# The language is again provided in an attribute of the root:
print(root.attrib)
# Out:
# {'language': 'nl'}

# %%
# Explore the first layer of xml tags:
for ch in root.getchildren():
    print(ch.tag)
    # Tip: Is there more information you can access at this point? Tip: explore text and attributes
# Out:
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file
# file

# %%
# Explore a single talk

## First extract all talks (hint: each file capture one talk)

talks = root.findall('file')
print(len(talks))

## Pick one talk to explore
test_talk = talks[12]
# Out:
# 1927

# %%
for ch in test_talk.getchildren():
    print(ch.tag)
# Out:
# head
# content

# %%
# explore the meta information:

head = test_talk.find('head')

for ch in head.getchildren():
    print(ch.tag)
# Out:
# url
# pagesize
# dtime
# encoding
# content-type
# keywords
# speaker
# talkid
# videourl
# videopath
# date
# title
# description
# transcription
# translators
# reviewers
# wordnum
# charnum

# %%
# explore the meta information:

content = test_talk.find('content')

for ch in content.getchildren():
    print(ch.tag)
    
content.text
# Out:
# 'Ik denk dat het geheim van het kweken van zeer droogte-tolerant gewas dat wellicht voor voedselzekerheid kan zorgen, in opstandingsplanten zit. Die zie je hier in extreem droge toestand. Je zou kunnen denken dat deze planten dood zijn, maar dat is niet zo. Als je ze water geeft, richten ze zich weer op en gaan groeien binnen 12 tot 48 uur.\nWaarom denk ik dat het kweken van droogte-tolerant gewas voedselzekerheid zou kunnen opleveren? De wereldbevolking is zo\'n 7 miljard. Men voorspelt dat deze rond 2050 zo\'n 9 tot 10 miljard is, met de sterkste groei in Afrika.\nDe voedsel- en agrarische organisaties hebben voorspeld dat er 70 procent groei nodig is van de huidige agrarische productie om in die vraag te voorzien. Planten staan aan de basis van de voedselketen dus zal het grootste aandeel moeten komen van planten.\nIn die 70 procent zijn de mogelijke gevolgen van de klimaatverandering nog niet opgenomen.\nDit komt uit een onderzoek door Dai, gepubliceerd in 2011, waarin hij alle mogelijke effecten van klimaatverandering meenam, zoals de toegenomen dorheid door gebrek aan regen. Deze rode plekken zijn gebieden waar tot voor kort met succes aan landbouw werd gedaan, maar nu niet meer vanwege gebrek aan regen. Dit is de voorspelling voor 2050. Een groot deel van Afrika, in feite van de wereld, komt in gevaar. We moeten slimme manieren bedenken om voedsel te produceren. Liefst ook met droogte-tolerante gewassen.\nJe moet ook onthouden over Afrika, dat de meeste landbouw er afhankelijk is van regen.\nDroogte-tolerant gewas kweken is niet zo makkelijk. Dat komt door het water. Water is van levensbelang op deze planeet. Alle levende organismen met stofwisseling, van microben tot jij en ik, zijn voornamelijk samengesteld uit water. Bij alle biologische processen is water nodig. Verlies van de minste hoeveelheid water veroorzaakt de dood. Jij en ik zijn voor 65 procent water -- een procent minder en we gaan dood. We kunnen ons wel aanpassen om dat te voorkomen. Planten kunnen dat niet. Ze zitten vast in de grond. In eerste instantie hebben ze iets meer water dan wij, ongeveer 95 procent, en ze kunnen iets meer verliezen dan wij, zo\'n 10 tot 70 procent, afhankelijk van welke soort, maar slechts korte tijd.\nDe meeste zullen proberen de droogte te weerstaan of verlies te vermijden. Extreme voorbeelden van zulke bikkels vind je onder de vetplanten. Ze zijn vaak klein en aantrekkelijk, maar ze houden water zó goed vast dat ze extreem langzaam groeien. Het beperken van waterverlies zie je bij sommige bomen en struiken. Hun wortels groeien erg diep, waar ze onderaards water vinden en zich daarmee steeds blijven spoelen, om zo vochtig te blijven.\nAan de rechterkant zie je de baobab. Ook wel de onderstebovenboom genoemd, omdat ze zoveel meer wortels dan takken hebben, dat het lijkt of de boom omgekeerd is geplant. De wortels zijn natuurlijk nodig voor de watervoorziening.\nDe meestgebruikte strategie tegen waterverlies vind je bij eenjarigen. Eenjarigen maken het grootste deel uit van ons plantaardige voedsel. Aan de westkust van mijn land zie je het grootste deel van het jaar niet veel vegetatie. Maar als de voorjaarsregen komt, krijg je dit: een bloeiende woestijn.\nDe strategie van eenjarigen is dat ze alleen in het regenseizoen groeien. Aan het eind van dat seizoen produceren ze zaad dat droog is, acht tot tien procent water, maar het leeft wel. En alles wat zo droog is, maar wel leeft, noemen we verdrogingstolerant.\nIn verdroogde toestand, kunnen de zaden in extreme omgevingen liggen gedurende langere tijd. Als het regenseizoen dan komt, ontkiemen ze en groeien, en start de hele kringloop opnieuw.\nHet wordt algemeen verondersteld dat de evolutie van verdrogingstolerante zaden kolonisatie en verspreiding mogelijk maakten van bloeiende planten of bedektzadigen op land.\nTerug naar de eenjarigen, als belangrijkste voedselleverancier. Graan, rijst en mais vormen 95 procent van ons plantaardige voedsel. Het is een goede strategie want i ...

# %% [markdown]
# # Assignment
#
# In this assignment, you will write code to explore the dataset. For instance, you will answer questions such as
#
# * How many talks are there in total? How many languages do the translations cover?
# * What is the oldest/latest talk?
# * Which speaker is most widely translated?
#
# Don't worry if you don't know how to solve these questions just now. You will start by working on the English talks (i.e. a single xml file). This will give you a feeling for the xml structure. You will write a number of small functions to extract information and compare talks. You should then be able to reuse your functions to explore the translations (i.e. work on multiple xml files).
#
# ## Part I: Analyze the original English talks
#
# This part of the assignment only requires you to analyze the content of the xml file containing the original talks (in English).
#
# Create a python scipt which give you the following information:
#
# * What is the longest talk (in terms of word count), what is the shortest talk (in terms of word count), what is the average word count? (id and title, numbers) (`find_length`)
# * Oldest and latest talk (id and title, dates) (`find_date`)
# * Is there a speaker with multiple talks? (function: `find_speaker`)
# * How many English talks are there in total? (No function required, you can simply use a built-in function on the list of all English talk elements.)
#
#
# Each of these aspects should be covered by a single function. Below, we give you some instructions about what the functions should do:
#
# * find_wc:
#     * input: list of all talk elements (positional), length (longest/shortest, keyword argument)
#     * output: title(s), id(s), mean word count
# * find_date:
#     * input: list of all talk elements (positional), time (latest/oldest, keyword argument)
#     * output: title(s), id(s)
# * find_speaker:
#     * input: list of talk elemenets (position)
#     * output: dict mapping speakers with more than one talk to their talks (tuple of talk title and id)
#
#
# The script should execute all functions.
#
# **Code structure**
#
# The script should only contain the functions listed above. If you use helper functions (highly recommended, see tips below), please put them in a script called `utils.py` and import them in the script called `ted_english_analysis.py`.
#
# You can use a main function (main()), which calls all functions (not compulsory).
#
# **Informative print statements**
#
# Please use print statements to indicate what the function outputs refer to. Please don't forget to print the total number of talks. We recommend using f-strings, for instance:
#
# ```
# n_talks = len(talks)
# print('In total, there are {n_talks} English Ted talks in the dataset.')
#
# The script should be called `ted_english_analysis.py` and execute all functions when called from the command line. Add print statements so the output can be interpreted. For example, you the script should print:
# ```
#
# ```
# The total number of English talks is: [total number]
#
# Talk length:
# Longest talk: [title] (id: [id])
# Shortest talk: [title] (id: [id])
# Mean word count: [mean word count]
# ```
#
# **Grading**
#
# You will receive points for the correct functions (and correct output), the print statements and the script(s).

# %% [markdown]
# **Recommended helper functions**
#
# We highly recommend definining small helper functions that extract information from a single talk element.
#
# First think about the different pieces of information you will need:
#
# * talk id
# * date
# * title
# * speaker
# * word count
#
# In addition, you want to load your file as an xml tree, access the root and extract all talks (as a list of xml elements). Tip: Use one element in the list to develop and test your helper functions.

# %%
# For example:

def load_root(path):
    tree = et.parse(path)
    root = tree.getroot()
    return root

def get_talks(root):
    talks = root.findall('file')
    return talks

path = '../Data/ted-talks/XML_releases/xml/ted_en-20160408.xml'
root = load_root(path)
talks = get_talks(root)

print(len(talks))

# This can be your test example
test_talk = talks[3]
# Out:
# 2085

# %%
# !python ted_english_analysis.py
# Out:
# The total number of talks given in english language are : 2085
#
# The lenth of the talk is : 7671
# <class 'list'>
# The longest talk is : Dan Gilbert: Why we make bad decisions and the talk id for the same is : 420
# The mean word count is : 2474.6076738609113
#
# The date of the talk is: 2016/02/19
# latest talk: Casey Gerald: The gospel of doubt (id: 2451)
# latest talk: Tshering Tobgay: This country isn't just carbon neutral -- it's carbon negative (id: 2452)
# The following is the collection of speakers and their talks:
# {'AJ Jacobs': [("AJ Jacobs: The world's largest family reunion … we're all "
#                 'invited!',
#                 '2021'),
#                ('AJ Jacobs: How healthy living nearly killed me', '1312'),
#                ('AJ Jacobs: My year of living biblically', '301')],
#  'Aakash Odedra': [('Aakash Odedra: A dance in a hurricane of paper, wind and '
#                     'light',
#                     '2147')],
#  'Aaron Huey': [("Aaron Huey: America's native prisoners of war", '1004')],
#  'Aaron Koblin': [('Aaron Koblin: Visualizing ourselves ... with crowd-sourced '
#                    'data',
#                    '1152')],
#  "Aaron O'Connell": [("Aaron O'Connell: Making sense of a visible quantum "
#                       'object',
#                       '1160')],
#  'Abe Davis': [("Abe Davis: New video technology that reveals an object's "
#                 'hidden properties',
#                 '2246')],
#  'Abha Dawesar': [('Abha Dawesar: Life in the "digital now"', '1856')],
#  'Abigail Washburn': [('Abigail Washburn: Building US-China relations ... by '
#                        'banjo',
#                        '1420')],
#  'Abraham Verghese': [("Abraham Verghese: A doctor's touch", '1231')],
#  'Achenyo Idachaba': [('Achenyo Idachaba: How I turned a deadly plant into a '
#                        'thriving business',
#                        '2407')],
#  'Adam Davidson': [('Adam Davidson: What we learned from teetering on the '
#                     'fiscal cliff',
#                     '1638')],
#  'Adam Foss': [("Adam Foss: A prosecutor's vision for a better justice system",
#                 '2453')],
#  'Adam Garone': [('Adam Garone: Healthier men, one moustache at a time',
#                   '1606')],
#  'Adam Grosser': [('Adam Grosser: A mobile fridge for vaccines', '285')],
#  'Adam Ostrow': [('Adam Ostrow: After your final status update', '1201')],
#  'Adam Sadowsky': [('Adam Sadowsky: How to engineer a viral music video',
#                     '877')],
#  'Adam Savage': [('Adam Savage: My obsession with objects and the stories they '
#                   'tell',
#                   '488')],
#  'Adam Spencer': [('Adam Spencer: Why I fell in love with monster prime '
#                    'numbers',
#                    '1811')],
#  'Aditi Shankardass': [('Aditi Shankardass: A second opinion on developmental '
#                         'disorders',
#                         '893')],
#  'Adora Svitak': [('Adora Svitak: What adults can learn from kids', '815')],
#  'Afra Raymond': [('Afra Raymond: Three myths about corruption', '1673')],
#  'Ahn Trio': [('Ahn Trio: A modern take on piano, violin, cello', '1083')],
#  'Aicha el-Wafi + Phyllis Rodriguez': [('Aicha el-Wafi + Phyllis Rodriguez: '
#                                         'The mothers who found forgiveness, '
#                                         'friendship',
#                                         '1136')],
#  'Aimee Mullins': [('Aimee Mullins: The opportunity of adversity', '769'),
#                    ('Aimee Mullins: My 12 pairs of legs', '482'),
#                    ('Aimee Mullins: Changing my legs - and my mindset', '443')],
#  'Ajit Narayanan': [('Ajit Narayanan: A word game to communicate in any '
#                      'language',
#                      '1934')],
#  'Al Gore': [('Al Gore: The case for optimism on climate change', '2441'),
#              ('Al Gore: What comes after An Inconvenient Truth?', '535'),
#              ('Al Gore: New thinking on the climate crisis', '243'),
#              ('Al Gore: Averting the climate crisis', '1')],
#  'Al Seckel': [('Al Seckel: Visual illusions that show how we (mis)think',
#                 '78')],
#  'Al Vernacchio': [("Al Vernacchio: Sex needs a new metaphor. Here's one ...",
#                     '1761')],
#  'Alaa Murabit': [('Alaa Murabit: What my religion really says about women',
#                    '2298')],
#  'Alain de Botton': [('Alain de Botton: Atheism 2.0', '1327'),
#                      ('Alain de Botton: A kinder, gentler philosophy of '
#                       'success',
#                       '605')],
#  'Alan Eustace': [("Alan Eustace: I leapt from the stratosphere. Here's how I "
#                    'did it',
#                    '2259')],
#  'Alan Kay': [('Alan Kay: A powerful idea about ideas', '228')],
#  'Alan Russell': [('Alan Russell: The potential of regenerative medicine',
#                    '142')],
#  'Alan Siegel': [("Alan Siegel: Let's simplify legal jargon!", '803')],
#  'Alanna Shaikh': [("Alanna Shaikh: How I'm preparing to get Alzheimer's",
#                     '1498')],
#  'Alastair Parvin': [('Alastair Parvin: Architecture for the people by the '
#                       'people',
#                       '1749')],
#  'Alberto Cairo': [('Alberto Cairo: There are no scraps of men', '1311')],
#  'Alec Soth + Stacey Baker': [('Alec Soth + Stacey Baker: This is what '
#                                'enduring love looks like',
#                                '2300')],
#  'Alejandro Aravena': [('Alejandro Aravena: My architectural philosophy? Bring '
#                         'the community into the process',
#                         '2128')],
#  'Alessandra Orofino': [('Alessandra Orofino: It’s our city. Let’s fix it',
#                          '2107')],
#  'Alessandro Acquisti': [('Alessandro Acquisti: What will a future without '
#                           'secrets look like?',
#                           '1848')],
#  'Alex Kipman': [('Alex Kipman: A futuristic vision of the age of holograms',
#                   '2461')],
#  'Alex Laskey': [('Alex Laskey: How behavioral science can lower your energy '
#                   'bill',
#                   '1754')],
#  'Alex Steffen': [('Alex Steffen: The shareable future of cities', '1207'),
#                   ('Alex Steffen: The route to a sustainable future', '74')],
#  'Alex Tabarrok': [('Alex Tabarrok: How ideas trump crises', '525')],
#  'Alex Wissner-Gross': [('Alex Wissner-Gross: A new equation for intelligence',
#                          '1922')],
#  'Alexa Meade': [('Alexa Meade: Your body is my canvas', '1814')],
#  'Alexander Betts': [("Alexander Betts: Our refugee system is failing. Here's "
#                       'how we can fix it',
#                       '2449')],
#  'Alexander Tsiaras': [('Alexander Tsiaras: Conception to birth -- visualized',
#                         '1270')],
#  'Alexis Ohanian': [('Alexis Ohanian: How to make a splash in social media',
#                      '714')],
#  'Ali Carr-Chellman': [('Ali Carr-Chellman: Gaming to re-engage boys in '
#                         'learning',
#                         '1053')],
#  'Alice Bows-Larkin': [('Alice Bows-Larkin: Climate change is happening. '
#                         "Here's how we adapt",
#                         '2339')],
#  'Alice Dreger': [('Alice Dreger: Is anatomy destiny?', '1166')],
#  'Alice Goffman': [("Alice Goffman: How we're priming some kids for college — "
#                     'and others for prison',
#                     '2247')],
#  'Alisa Miller': [('Alisa Miller: How the news distorts our worldview', '248')],
#  'Alison Gopnik': [('Alison Gopnik: What do babies think?', '1241')],
#  'Alison Jackson': [('Alison Jackson: An unusual glimpse at celebrity', '210')],
#  'Alison Killing': [('Alison Killing: What happens when a city runs out of '
#                      'room for its dead',
#                      '2393'),
#                     ('Alison Killing: There’s a better way to die, and '
#                      'architecture can help',
#                      '2212')],
#  'Alix Generous': [('Alix Generous: How I learned to communicate my inner life '
#                     "with Asperger's",
#                     '2310')],
#  'Allan Adams': [('Allan Adams: What the discovery of gravitational waves '
#                   'means',
#                   '2439'),
#                  ('Allan Adams: The discovery that could rewrite physics',
#                   '1963')],
#  'Allan Jones': [('Allan Jones: A map of the brain', '1267')],
#  'Allan Savory': [('Allan Savory: How to fight desertification and reverse '
#                    'climate change',
#                    '1683')],
#  'Allison Hunt': [('Allison Hunt: How to get (a new) hip', '149')],
#  'Alwar Balasubramaniam': [('Alwar Balasubramaniam: Art of substance and '
#                             'absence',
#                             '950')],
#  'Alyson McGregor': [('Alyson McGregor: Why medicine often has dangerous side '
#                       'effects for women',
#                       '2349')],
#  'Amanda Bennett': [('Amanda Bennett: We need a heroic narrative for death',
#                      '1847')],
#  'Amanda Burden': [('Amanda Burden: How public spaces make cities work',
#                     '1966')],
#  'Amanda Palmer': [('Amanda Palmer: The art of asking', '1682')],
#  'Amber Case': [('Amber Case: We are all cyborgs now', '1050')],
#  'Ameenah Gurib-Fakim': [('Ameenah Gurib-Fakim: Humble plants that hide '
#                           'surprising secrets',
#                           '2127')],
#  'Ami Klin': [('Ami Klin: A new way to diagnose autism', '1472')],
#  'Amit Sood': [('Amit Sood: Building a museum of museums on the web', '1144')],
#  'Amory Lovins': [('Amory Lovins: A 40-year plan for energy', '1434'),
#                   ('Amory Lovins: Winning the oil endgame', '51')],
#  'Amos Winter': [('Amos Winter: The cheap all-terrain wheelchair', '1616')],
#  'Amy Cuddy': [('Amy Cuddy: Your body language shapes who you are', '1569')],
#  'Amy Lockwood': [('Amy Lockwood: Selling condoms in the Congo', '1228')],
#  'Amy Purdy': [('Amy Purdy: Living beyond limits', '1285')],
#  'Amy Smith': [('Amy Smith: Simple designs to save a life', '2')],
#  'Amy Tan': [('Amy Tan: Where does creativity hide?', '250')],
#  'Amy Webb': [('Amy Webb: How I hacked online dating', '1833')],
#  'Anand Agarawala': [('Anand Agarawala: Rethink the desktop with BumpTop',
#                       '131')],
#  'Anand Giridharadas': [('Anand Giridharadas: A tale of two Americas. And the '
#                          'mini-mart where they collided',
#                          '2219')],
#  'Anand Varma': [('Anand Varma: The first 21 days of a bee’s life', '2249')],
#  'Ananda Shankar Jayant': [('Ananda Shankar Jayant: Fighting cancer with dance',
#                             '888')],
#  'Anant Agarwal': [('Anant Agarwal: Why massive open online courses (still) '
#                     'matter',
#                     '1913')],
#  'Anas Aremeyaw Anas': [('Anas Aremeyaw Anas: How I named, shamed and jailed',
#                          '1757')],
#  'Anastasia Taylor-Lind': [('Anastasia Taylor-Lind: Fighters and mourners of '
#                             'the Ukrainian revolution',
#                             '2146')],
#  'Anders Fjellberg': [('Anders Fjellberg: Two nameless bodies washed up on the '
#                        'beach. Here are their stories',
#                        '2353')],
#  'Anders Ynnerman': [('Anders Ynnerman: Visualizing the medical data explosion',
#                       '1057')],
#  'Andras Forgacs': [('Andras Forgacs: Leather and meat without killing animals',
#                      '1824')],
#  'Andrea Ghez': [('Andrea Ghez: The hunt for a supermassive black hole',
#                   '701')],
#  'Andreas Ekström': [('Andreas Ekström: The moral bias behind your search '
#                       'results',
#                       '2369')],
#  'Andreas Raptopoulos': [('Andreas Raptopoulos: No roads? There’s a drone for '
#                           'that',
#                           '1876')],
#  'Andreas Schleicher': [('Andreas Schleicher: Use data to build better schools',
#                          '1667')],
#  'Andres Lozano': [("Andres Lozano: Parkinson's, depression and the switch "
#                     'that might turn them off',
#                     '1717')],
#  'Andrew Bastawrous': [('Andrew Bastawrous: Get your next eye exam on a '
#                         'smartphone',
#                         '1987')],
#  'Andrew Bird': [('Andrew Bird: A one-man orchestra of the imagination',
#                   '1001')],
#  'Andrew Blum': [('Andrew Blum: Discover the physical side of the internet',
#                   '1576')],
#  'Andrew Connolly': [("Andrew Connolly: What's the next window into our "
#                       'universe?',
#                       '2069')],
#  'Andrew Fitzgerald': [('Andrew Fitzgerald: Adventures in Twitter fiction',
#                         '1841')],
#  'Andrew McAfee': [('Andrew McAfee: What will future jobs look like?', '1759'),
#                    ('Andrew McAfee: Are droids taking our jobs?', '1574')],
#  'Andrew Mwenda': [('Andrew Mwenda: Aid for Africa? No thanks.', '159')],
#  'Andrew Solomon': [('Andrew Solomon: How the worst moments in our lives make '
#                      'us who we are',
#                      '2005'),
#                     ('Andrew Solomon: Depression, the secret we share', '1894'),
#                     ('Andrew Solomon: Love, no matter what', '1756')],
#  'Andrew Stanton': [('Andrew Stanton: The clues to a great story', '1379')],
#  'Andrés Ruzo': [('Andrés Ruzo: How I found a mythical boiling river in the '
#                   'Amazon',
#                   '2424')],
#  'Andy Hobsbawm': [('Andy Hobsbawm: Do the green thing', '407')],
#  'Andy Puddicombe': [('Andy Puddicombe: All it takes is 10 mindful minutes',
#                       '1640')],
#  'Andy Yen': [("Andy Yen: Think your email's private? Think again", '2204')],
#  'Angela Belcher': [('Angela Belcher: Using nature to grow batteries', '1133')],
#  'Angela Lee Duckworth': [('Angela Lee Duckworth: The key to success? Grit',
#                            '1733')],
#  'Angela Patton': [('Angela Patton: A father-daughter dance ... in prison',
#                     '1646')],
#  'Angelo Vermeulen': [('Angelo Vermeulen: How to go to space, without having '
#                        'to go to space',
#                        '2197')],
#  'Angélica Dass': [('Angélica Dass: The beauty of human skin in every color',
#                     '2463')],
#  'Anil Ananthaswamy': [('Anil Ananthaswamy: What it takes to do extreme '
#                         'astrophysics',
#                         '1129')],
#  'Anil Gupta': [("Anil Gupta: India's hidden hotbeds of invention", '851')],
#  'Ann Cooper': [("Ann Cooper: What's wrong with school lunches", '348')],
#  'Ann Morgan': [('Ann Morgan: My year reading a book from every country in the '
#                  'world',
#                  '2382')],
#  'AnnMarie Thomas': [('AnnMarie Thomas: Hands-on science with squishy circuits',
#                       '1111')],
#  'Anna Deavere Smith': [('Anna Deavere Smith: Four American characters', '60')],
#  'Anna Mracek Dietrich': [('Anna Mracek Dietrich: A plane you can drive',
#                            '1260')],
#  'Anne Curzan': [('Anne Curzan: What makes a word "real"?', '2022')],
#  'Anne Milgram': [('Anne Milgram: Why smart statistics are the key to fighting '
#                    'crime',
#                    '1914')],
#  'Anne-Marie Slaughter': [('Anne-Marie Slaughter: Can we all "have it all"?',
#                            '1943')],
#  'Annette Heuser': [('Annette Heuser: The 3 agencies with the power to make or '
#                      'break economies',
#                      '1937')],
#  'Annie Lennox': [('Annie Lennox: Why I am an HIV/AIDS activist', '963')],
#  'Annie Murphy Paul': [("Annie Murphy Paul: What we learn before we're born",
#                         '1289')],
#  'Anote Tong': [('Anote Tong: My country will be underwater soon -- unless we '
#                  'work together',
#                  '2379')],
#  'Anthony Atala': [('Anthony Atala: Printing a human kidney', '1088'),
#                    ('Anthony Atala: Growing new organs', '744')],
#  'Antonio Damasio': [('Antonio Damasio: The quest to understand consciousness',
#                       '1308')],
#  'Antonio Donato Nobre': [('Antonio Donato Nobre: The magic of the Amazon: A '
#                            'river that flows invisibly all around us',
#                            '2088')],
#  'Antony Gormley': [('Antony Gormley: Sculpted space, within and without',
#                      '1551')],
#  'António Guterres': [('António Guterres: Refugees have the right to be '
#                        'protected',
#                        '2397')],
#  'Anupam Mishra': [('Anupam Mishra: The ancient ingenuity of water harvesting',
#                     '702')],
#  'Aomawa Shields': [("Aomawa Shields: How we'll find life on other planets",
#                      '2402')],
#  'Aparna Rao': [('Aparna Rao: Art that craves your attention', '1921'),
#                 ('Aparna Rao: High-tech art (with a sense of humor)', '1265')],
#  'Apollo Robbins': [('Apollo Robbins: The art of misdirection', '1821')],
#  'Arianna Huffington': [('Arianna Huffington: How to succeed? Get more sleep',
#                          '1044')],
#  'Ariel Garten': [('Ariel Garten: Know thyself, with a brain scanner', '1338')],
#  'Aris Venetikidis': [('Aris Venetikidis: Making sense of maps', '1582')],
#  'Arthur Benjamin': [('Arthur Benjamin: The magic of Fibonacci numbers',
#                       '1862'),
#                      ('Arthur Benjamin: Teach statistics before calculus!',
#                       '587'),
#                      ('Arthur Benjamin: A performance of "Mathemagic"', '199')],
#  'Arthur Brooks': [("Arthur Brooks: A conservative's plea: Let's work together",
#                     '2456')],
#  'Arthur Ganson': [('Arthur Ganson: Moving sculpture', '267')],
#  'Arthur Potts Dawson': [('Arthur Potts Dawson: A vision for sustainable '
#                           'restaurants',
#                           '1020')],
#  'Arunachalam Muruganantham': [('Arunachalam Muruganantham: How I started a '
#                                 'sanitary napkin revolution!',
#                                 '1614')],
#  'Arvind Gupta': [('Arvind Gupta: Turning trash into toys for learning',
#                    '1135')],
#  'Ash Beckham': [('Ash Beckham: When to take a stand -- and when to let it go',
#                   '2282'),
#                  ("Ash Beckham: We're all hiding something. Let's find the "
#                   'courage to open up',
#                   '1932')],
#  'Asha de Vos': [('Asha de Vos: Why you should care about whale poo', '2160')],
#  'Asher Hasan': [('Asher Hasan: My message of peace from Pakistan', '719')],
#  'Ashraf Ghani': [('Ashraf Ghani: How to rebuild a broken state', '3')],
#  'Aspen Baker': [('Aspen Baker: A better way to talk about abortion', '2297')],
#  'Atul Gawande': [('Atul Gawande: How do we heal medicine?', '1421')],
#  'Aubrey de Grey': [('Aubrey de Grey: A roadmap to end aging', '39')],
#  'Audrey Choi': [('Audrey Choi: How to make a profit while making a difference',
#                   '2431')],
#  'Auke Ijspeert': [('Auke Ijspeert: A robot that runs and swims like a '
#                     'salamander',
#                     '2419')],
#  'Auret van Heerden': [('Auret van Heerden: Making global labor fair', '1005')],
#  'Avi Reichental': [('Avi Reichental: What’s next in 3D printing', '2026')],
#  'Avi Rubin': [('Avi Rubin: All your devices can be hacked', '1370')],
#  'Ayah Bdeir': [('Ayah Bdeir: Building blocks that blink, beep and teach',
#                  '1404')],
#  'Aziz Abu Sarah': [('Aziz Abu Sarah: For more tolerance, we need more ... '
#                      'tourism?',
#                      '2161')],
#  'Aziza Chaouni': [('Aziza Chaouni: How I brought a river, and my city, back '
#                     'to life',
#                     '2064')],
#  'BJ Miller': [('BJ Miller: What really matters at the end of life', '2325')],
#  'BLACK': [('BLACK: My journey to yo-yo mastery', '1716')],
#  'Baba Shiv': [("Baba Shiv: Sometimes it's good to give up the driver's seat",
#                 '1514')],
#  'Bahia Shehab': [('Bahia Shehab: A thousand times no', '1537')],
#  'Bandi Mbubi': [('Bandi Mbubi: Demand a fair trade cell phone', '1567')],
#  'Barat Ali Batoor': [('Barat Ali Batoor: My desperate journey with a human '
#                        'smuggler',
#                        '2231')],
#  'Barbara Block': [('Barbara Block: Tagging tuna in the deep ocean', '973')],
#  'Barbara Natterson-Horowitz': [('Barbara Natterson-Horowitz: What '
#                                  "veterinarians know that physicians don't",
#                                  '2145')],
#  'Barry Schuler': [('Barry Schuler: Genomics 101', '437')],
#  'Barry Schwartz': [('Barry Schwartz: The way we think about work is broken',
#                      '2324'),
#                     ('Barry Schwartz: Using our practical wisdom', '1043'),
#                     ('Barry Schwartz: Our loss of wisdom', '462'),
#                     ('Barry Schwartz: The paradox of choice', '93')],
#  'Bart Knols': [('Bart Knols: 3 new ways to kill mosquitoes', '1445')],
#  'Bart Weetjens': [('Bart Weetjens: How I taught rats to sniff out land mines',
#                     '1019')],
#  'Barton Seaver': [("Barton Seaver: Sustainable seafood? Let's get smart",
#                     '993')],
#  'Bassam Tariq': [('Bassam Tariq: The beauty and diversity of Muslim life',
#                    '2169')],
#  'Bastian Schaefer': [('Bastian Schaefer: A 3D-printed jumbo jet?', '1798')],
#  'Beardyman': [('Beardyman: The polyphonic me', '1804')],
#  'Beau Lotto': [('Beau Lotto: Optical illusions show how we see', '653')],
#  "Beau Lotto + Amy O'Toole": [("Beau Lotto + Amy O'Toole: Science is for "
#                                'everyone, kids included',
#                                '1587')],
#  'Becci Manson': [('Becci Manson: (Re)touching lives through photos', '1532')],
#  'Becky  Blanton': [('Becky  Blanton: The year I was homeless', '669')],
#  'Beeban Kidron': [('Beeban Kidron: The shared wonder of film', '1476')],
#  'Bel Pesce': [('Bel Pesce: 5 ways to kill your dreams', '2200')],
#  'Ben Ambridge': [('Ben Ambridge: 10 myths about psychology, debunked',
#                    '2178')],
#  'Ben Cameron': [('Ben Cameron: Why the live arts matter', '952')],
#  'Ben Dunlap': [('Ben Dunlap: The life-long learner', '208')],
#  'Ben Goldacre': [("Ben Goldacre: What doctors don't know about the drugs they "
#                    'prescribe',
#                    '1575'),
#                   ('Ben Goldacre: Battling bad science', '1234')],
#  'Ben Kacyra': [('Ben Kacyra: Ancient wonders captured in 3D', '1266')],
#  'Ben Katchor': [('Ben Katchor: Comics of bygone New York', '524')],
#  'Ben Saunders': [('Ben Saunders: To the South Pole and back — the hardest 105 '
#                    'days of my life',
#                    '2143'),
#                   ('Ben Saunders: Why bother leaving the house?', '1631'),
#                   ('Ben Saunders: Why did I ski to the North Pole?', '89')],
#  'Ben Wellington': [('Ben Wellington: How we found the worst place to park in '
#                      'New York City -- using big data',
#                      '2199')],
#  'Benedetta Berti': [('Benedetta Berti: The surprising way groups like ISIS '
#                       'stay in power',
#                       '2309')],
#  'Benjamin Barber': [('Benjamin Barber: Why mayors should rule the world',
#                       '1825')],
#  'Benjamin Wallace': [('Benjamin Wallace: The price of happiness', '419')],
#  'Benjamin Zander': [('Benjamin Zander: The transformative power of classical '
#                       'music',
#                       '286')],
#  'Benoit Mandelbrot': [('Benoit Mandelbrot: Fractals and the art of roughness',
#                         '909')],
#  'Bernie Krause': [('Bernie Krause: The voice of the natural world', '1788')],
#  'Bertrand Piccard': [('Bertrand Piccard: My solar-powered adventure', '723')],
#  'Beth Noveck': [('Beth Noveck: Demand a more open-source government', '1558')],
#  'Beverly + Dereck Joubert': [('Beverly + Dereck Joubert: Life lessons from '
#                                'big cats',
#                                '1039')],
#  'Bilal Bomani': [('Bilal Bomani: Plant fuels that could power a jet', '1332')],
#  'Bill Clinton': [('Bill Clinton: My wish: Rebuilding Rwanda', '85')],
#  'Bill Davenhall': [('Bill Davenhall: Your health depends on where you live',
#                      '748')],
#  'Bill Doyle': [('Bill Doyle: Treating cancer with electric fields', '1343')],
#  'Bill Ford': [('Bill Ford: A future beyond traffic gridlock', '1174')],
#  'Bill Gates': [('Bill Gates: The next outbreak? We’re not ready', '2225'),
#                 ('Bill Gates: Teachers need real feedback', '1739'),
#                 ('Bill Gates: How state budgets are breaking US schools',
#                  '1087'),
#                 ('Bill Gates: Innovating to zero!', '767'),
#                 ('Bill Gates: Mosquitos, malaria and education', '451')],
#  'Bill Gross': [('Bill Gross: The single biggest reason why startups succeed',
#                  '2272'),
#                 ('Bill Gross: A solar energy system that tracks the sun',
#                  '450')],
#  'Bill Joy': [("Bill Joy: What I'm worried about, what I'm excited about",
#                '405')],
#  'Bill Stone': [("Bill Stone: I'm going to the moon. Who's with me?", '141')],
#  'Bill Strickland': [('Bill Strickland: Rebuilding a neighborhood with beauty, '
#                       'dignity, hope',
#                       '209')],
#  'Bill T. Jones': [('Bill T. Jones: The dancer, the singer, the cellist ... '
#                     'and a moment of creative magic',
#                     '2242')],
#  'Bill and Melinda Gates': [('Bill and Melinda Gates: Why giving away our '
#                              "wealth has been the most satisfying thing we've "
#                              'done',
#                              '1964')],
#  'Billie Jean King': [('Billie Jean King: This tennis icon paved the way for '
#                        'women in sports',
#                        '2327')],
#  'Billy Collins': [('Billy Collins: Two poems about what dogs think (probably)',
#                     '2031'),
#                    ('Billy Collins: Everyday moments, caught in time', '1398')],
#  'Billy Graham': [('Billy Graham: On technology and faith', '308')],
#  'Birke Baehr': [("Birke Baehr: What's wrong with our food system", '1016')],
#  'Bjarke Ingels': [('Bjarke Ingels: 3 warp-speed architecture tales', '634')],
#  'Bjorn Lomborg': [('Bjorn Lomborg: Global priorities bigger than climate '
#                     'change',
#                     '62')],
#  'Blaise Agüera y Arcas': [('Blaise Agüera y Arcas: Augmented-reality maps',
#                             '766'),
#                            ('Blaise Agüera y Arcas: How PhotoSynth can connect '
#                             "the world's images",
#                             '129')],
#  'Boaz Almog': [('Boaz Almog: The levitating superconductor', '1495')],
#  'Bob Mankoff': [('Bob Mankoff: Anatomy of a New Yorker cartoon', '1776')],
#  'Bobby Ghosh': [('Bobby Ghosh: Why global jihad is losing', '1623')],
#  'Boghuma Kabisen Titanji': [('Boghuma Kabisen Titanji: Ethical riddles in HIV '
#                               'research',
#                               '1645')],
#  'Boniface Mwangi': [('Boniface Mwangi: The day I stood up alone', '2221')],
#  'Bonnie Bassler': [('Bonnie Bassler: How bacteria "talk"', '509')],
#  'Bono': [("Bono: The good news on poverty (Yes, there's good news)", '1691'),
#           ('Bono: My wish: Three actions for Africa', '59')],
#  'Boyd Varty': [('Boyd Varty: What I learned from Nelson Mandela', '1890')],
#  'Bran Ferren': [("Bran Ferren: To create for the ages, let's combine art and "
#                   'engineering',
#                   '1956')],
#  'Brenda Laurel': [('Brenda Laurel: Why not make video games for girls?',
#                     '474')],
#  'Brenda Romero': [('Brenda Romero: Gaming for understanding', '1432')],
#  'Brené Brown': [('Brené Brown: Listening to shame', '1391'),
#                  ('Brené Brown: The power of vulnerability', '1042')],
#  'Brewster Kahle': [('Brewster Kahle: A free digital library', '346')],
#  'Brian Cox': [('Brian Cox: Why we need the explorers', '876'),
#                ('Brian Cox: What went wrong at the LHC', '531'),
#                ("Brian Cox: CERN's supercollider", '253')],
#  'Brian Dettmer': [('Brian Dettmer: Old books reborn as art', '2180')],
#  'Brian Goldman': [('Brian Goldman: Doctors make mistakes. Can we talk about '
#                     'that?',
#                     '1337')],
#  'Brian Greene': [('Brian Greene: Is our universe the only universe?', '1426'),
#                   ('Brian Greene: Making sense of string theory', '251')],
#  'Brian Skerry': [("Brian Skerry: The ocean's glory -- and horror", '873')],
#  'Britta Riley': [('Britta Riley: A garden in my apartment', '1284')],
#  'Bruce Aylward': [('Bruce Aylward: Humanity vs. Ebola. How we could win a '
#                     'terrifying war',
#                     '2177'),
#                    ("Bruce Aylward: How we'll stop polio for good", '1153')],
#  'Bruce Bueno de Mesquita': [('Bruce Bueno de Mesquita: A prediction for the '
#                               'future of Iran',
#                               '507')],
#  'Bruce Feiler': [('Bruce Feiler: Agile programming -- for your family',
#                    '1675'),
#                   ('Bruce Feiler: The council of dads', '1062')],
#  'Bruce McCall': [('Bruce McCall: What is retro-futurism?', '489')],
#  'Bruce Schneier': [('Bruce Schneier: The security mirage', '1132')],
#  'Bruno Bowden + Rufus Cappadocia': [('Bruno Bowden + Rufus Cappadocia: '
#                                       'Blindfold origami and cello',
#                                       '322')],
#  'Bruno Maisonnier': [('Bruno Maisonnier: Dance, tiny robots!', '1677')],
#  'Bruno Torturra': [('Bruno Torturra: Got a smartphone? Start broadcasting',
#                      '2154')],
#  'Bryan Stevenson': [('Bryan Stevenson: We need to talk about an injustice',
#                       '1378')],
#  'Bunker Roy': [('Bunker Roy: Learning from a barefoot movement', '1248')],
#  'Burt Rutan': [('Burt Rutan: The real future of space exploration', '4')],
#  'Béatrice Coron': [('Béatrice Coron: Stories cut from paper', '1257')],
#  'C.K. Williams': [('C.K. Williams: Poetry of youth and age', '500')],
#  "Caitria + Morgan O'Neill": [("Caitria + Morgan O'Neill: How to step up in "
#                                'the face of disaster',
#                                '1545')],
#  'Caleb Chung': [('Caleb Chung: Playtime with Pleo, your robotic dinosaur '
#                   'friend',
#                   '350')],
#  'Caleb Harper': [('Caleb Harper: This computer will grow your food in the '
#                    'future',
#                    '2432')],
#  'Cameron Herold': [("Cameron Herold: Let's raise kids to be entrepreneurs",
#                      '887')],
#  'Cameron Russell': [("Cameron Russell: Looks aren't everything. Believe me, "
#                       "I'm a model.",
#                       '1647')],
#  'Cameron Sinclair': [('Cameron Sinclair: The refugees of boom-and-bust',
#                        '681'),
#                       ('Cameron Sinclair: My wish: A call for open-source '
#                        'architecture',
#                        '54')],
#  'Camille Seaman': [('Camille Seaman: Photos from a storm chaser', '1763'),
#                     ('Camille Seaman: Haunting photos of polar ice', '1171')],
#  'Candy Chang': [('Candy Chang: Before I die I want to ...', '1553')],
#  'Carin Bondar': [('Carin Bondar: The birds and the bees are just the '
#                    'beginning',
#                    '1945')],
#  'Carl Honoré': [('Carl Honoré: In praise of slowness', '73')],
#  'Carl Safina': [('Carl Safina: What are animals thinking and feeling?',
#                   '2373'),
#                  ("Carl Safina: The oil spill's unseen villains -- and victims",
#                   '914')],
#  'Carl Schoonover': [('Carl Schoonover: How to look inside the brain', '1450')],
#  'Carlo Ratti': [('Carlo Ratti: Architecture that senses and responds',
#                   '1137')],
#  'Carmen Agra Deedy': [('Carmen Agra Deedy: Once upon a time, my mother ...',
#                         '347')],
#  'Carne Ross': [('Carne Ross: An independent diplomat', '951')],
#  'Carol Dweck': [('Carol Dweck: The power of believing that you can improve',
#                   '2156')],
#  'Carol Fishman Cohen': [('Carol Fishman Cohen: How to get back to work after '
#                           'a career break',
#                           '2469')],
#  'Caroline Casey': [('Caroline Casey: Looking past limits', '1116')],
#  'Caroline Lavelle': [('Caroline Lavelle: Casting a spell on the cello',
#                        '101')],
#  'Caroline Phillips': [('Caroline Phillips: Hurdy-gurdy for beginners', '959')],
#  'Carolyn Porco': [('Carolyn Porco: Could a Saturn moon harbor life?', '551'),
#                    ('Carolyn Porco: This is Saturn', '178')],
#  'Carolyn Steel': [('Carolyn Steel: How food shapes our cities', '650')],
#  'Carter Emmart': [('Carter Emmart: A 3D atlas of the universe', '900')],
#  'Cary Fowler': [('Cary Fowler: One seed at a time, protecting the future of '
#                   'food',
#                   '622')],
#  'Casey Gerald': [('Casey Gerald: The gospel of doubt', '2451')],
#  'Catarina Mota': [('Catarina Mota: Play with smart materials', '1692')],
#  'Catherine Bracy': [('Catherine Bracy: Why good hackers make good citizens',
#                       '1933')],
#  'Catherine Crump': [('Catherine Crump: The small and surprisingly dangerous '
#                       'detail the police track about you',
#                       '2149')],
#  'Catherine Mohr': [('Catherine Mohr: The tradeoffs of building green', '828'),
#                     ("Catherine Mohr: Surgery's past, present and robotic "
#                      'future',
#                      '580')],
#  'Celeste Headlee': [('Celeste Headlee: 10 ways to have a better conversation',
#                       '2435')],
#  'Cesar Harada': [('Cesar Harada: How I teach kids to love science', '2363'),
#                   ('Cesar Harada: A novel idea for cleaning up oil spills',
#                    '1499')],
#  'Cesar Kuriyama': [('Cesar Kuriyama: One second every day', '1663')],
#  'Chade-Meng Tan': [('Chade-Meng Tan: Everyday compassion at Google', '1113')],
#  'Charity Tillemann-Dick': [('Charity Tillemann-Dick: Singing after a double '
#                              'lung transplant',
#                              '1055')],
#  'Charles Anderson': [('Charles Anderson: Dragonflies that fly across oceans',
#                        '715')],
#  'Charles Elachi': [('Charles Elachi: The story behind the Mars Rovers',
#                      '399')],
#  'Charles Fleischer': [('Charles Fleischer: All things are Moleeds', '738')],
#  'Charles Hazlewood': [('Charles Hazlewood: Trusting the ensemble', '1240')],
#  'Charles Leadbeater': [('Charles Leadbeater: Education innovation in the '
#                          'slums',
#                          '892'),
#                         ('Charles Leadbeater: The era of open innovation',
#                          '63')],
#  'Charles Limb': [('Charles Limb: Building the musical muscle', '1291'),
#                   ('Charles Limb: Your brain on improv', '1046')],
#  'Charles Moore': [('Charles Moore: Seas of plastic', '470')],
#  'Charles Robertson': [("Charles Robertson: Africa's next boom", '1851')],
#  'Charlie Todd': [('Charlie Todd: The shared experience of absurdity', '1269')],
#  'Charmian Gooch': [('Charmian Gooch: My wish: To launch a new era of openness '
#                      'in business',
#                      '1949'),
#                     ("Charmian Gooch: Meet global corruption's hidden players",
#                      '1784')],
#  'Chelsea Shields': [("Chelsea Shields: How I'm working for change inside my "
#                       'church',
#                       '2372')],
#  'Cheryl Hayashi': [('Cheryl Hayashi: The magnificence of spider silk',
#                      '1296')],
#  'Chieko Asakawa': [('Chieko Asakawa: How new technology helps blind people '
#                      'explore the world',
#                      '2383')],
#  'Chimamanda Ngozi Adichie': [('Chimamanda Ngozi Adichie: The danger of a '
#                                'single story',
#                                '652')],
#  'Chip Conley': [('Chip Conley: Measuring what makes life worthwhile', '889')],
#  'Chip Kidd': [('Chip Kidd: The art of first impressions -- in design and life',
#                 '2287'),
#                ('Chip Kidd: Designing books is no laughing matter. OK, it is.',
#                 '1410')],
#  'Chris Abani': [('Chris Abani: On humanity', '294'),
#                  ('Chris Abani: Telling stories from Africa', '155')],
#  'Chris Anderson': [('Chris Anderson: How web video powers global innovation',
#                      '955'),
#                     ("Chris Anderson: TED's nonprofit transition", '211'),
#                     ("Chris Anderson: Technology's long tail", '72')],
#  'Chris Bangle': [('Chris Bangle: Great cars are great art', '5')],
#  'Chris Bliss': [('Chris Bliss: Comedy is translation', '1365')],
#  'Chris Burkard': [('Chris Burkard: The joy of surfing in ice-cold water',
#                     '2255')],
#  'Chris Domas': [('Chris Domas: The 1s and 0s behind cyber warfare', '2035')],
#  'Chris Downey': [('Chris Downey: Design with the blind in mind', '1863')],
#  'Chris Gerdes': [('Chris Gerdes: The future race car -- 150mph, and no driver',
#                    '1506')],
#  'Chris Hadfield': [('Chris Hadfield: What I learned from going blind in space',
#                      '1951')],
#  'Chris Jordan': [('Chris Jordan: Turning powerful stats into art', '279')],
#  'Chris Kluwe': [('Chris Kluwe: How augmented reality will change sports ... '
#                   'and build empathy',
#                   '2007')],
#  'Chris McKnett': [('Chris McKnett: The investment logic for sustainability',
#                     '1927')],
#  'Chris Milk': [('Chris Milk: How virtual reality can create the ultimate '
#                  'empathy machine',
#                  '2228')],
#  'Chris Urmson': [('Chris Urmson: How a driverless car sees the road', '2291')],
#  'Christien Meindertsma': [('Christien Meindertsma: How pig parts make the '
#                             'world turn',
#                             '960')],
#  'Christina Warinner': [('Christina Warinner: Tracking ancient diseases using '
#                          '... plaque',
#                          '1425')],
#  'Christine Sun Kim': [('Christine Sun Kim: The enchanting music of sign '
#                         'language',
#                         '2357')],
#  'Christoph Adami': [("Christoph Adami: Finding life we can't imagine",
#                       '1237')],
#  'Christopher "moot" Poole"': [('Christopher "moot" Poole": The case for '
#                                 'anonymity online',
#                                 '874')],
#  'Christopher C. Deam': [('Christopher C. Deam: The Airstream, restyled',
#                           '503')],
#  'Christopher Emdin': [('Christopher Emdin: Teach teachers how to create magic',
#                         '1965')],
#  'Christopher McDougall': [('Christopher McDougall: Are we born to run?',
#                             '1067')],
#  'Christopher Ryan': [('Christopher Ryan: Are we designed to be sexual '
#                        'omnivores?',
#                        '1931')],
#  'Christopher Soghoian': [('Christopher Soghoian: How to avoid surveillance '
#                            '... with the phone in your pocket',
#                            '2314'),
#                           ('Christopher Soghoian: Government surveillance — '
#                            'this is just the beginning',
#                            '1940')],
#  'Christopher deCharms': [('Christopher deCharms: A look inside the brain in '
#                            'real time',
#                            '236')],
#  'Chrystia Freeland': [('Chrystia Freeland: The rise of the new global '
#                         'super-rich',
#                         '1791')],
#  'Claron McFadden': [('Claron McFadden: Singing the primal mystery', '1105')],
#  'Clay Shirky': [('Clay Shirky: How the Internet will (one day) transform '
#                   'government',
#                   '1546'),
#                  ('Clay Shirky: Why SOPA is a bad idea', '1329'),
#                  ('Clay Shirky: How cognitive surplus will change the world',
#                   '896'),
#                  ('Clay Shirky: How social media can make history', '575'),
#                  ('Clay Shirky: Institutions vs. collaboration', '274')],
#  'Clayton Cameron': [('Clayton Cameron: A-rhythm-etic. The math behind the '
#                       'beats',
#                       '1923')],
#  'Clifford Stoll': [('Clifford Stoll: The call to learn', '237')],
#  'Clint Smith': [('Clint Smith: How to raise a black son in America', '2240'),
#                  ('Clint Smith: The danger of silence', '2059')],
#  'Colin Camerer': [("Colin Camerer: When you're making a deal, what's going on "
#                     'in your brain?',
#                     '1701')],
#  'Colin Grant': [('Colin Grant: How our stories cross over', '2074')],
#  'Colin Powell': [('Colin Powell: Kids need structure', '1649')],
#  'Colin Stokes': [('Colin Stokes: How movies teach manhood', '1650')],
#  'Conrad Wolfram': [('Conrad Wolfram: Teaching kids real math with computers',
#                      '1007')],
#  'Corneille Ewango': [('Corneille Ewango: A hero of the Congo forest', '299')],
#  'Cosmin Mihaiu': [('Cosmin Mihaiu: Physical therapy is boring -- play a game '
#                     'instead',
#                     '2257')],
#  'Courtney Martin': [("Courtney Martin: This isn't her mother's feminism",
#                       '1089')],
#  'Craig Venter': [('Craig Venter: Watch me unveil "synthetic life"', '863'),
#                   ('Craig Venter: On the verge of creating synthetic life',
#                    '227'),
#                   ("Craig Venter: Sampling the ocean's DNA", '6')],
#  'Cristina Domenech': [('Cristina Domenech: Poetry that frees the soul',
#                         '2163')],
#  'Cynthia Breazeal': [('Cynthia Breazeal: The rise of personal robots',
#                        '1070')],
#  'Cynthia Kenyon': [('Cynthia Kenyon: Experiments that hint of longer lives',
#                      '1274')],
#  'Cynthia Schneider': [('Cynthia Schneider: The surprising spread of Idol TV',
#                         '684')],
#  'Dale Dougherty': [('Dale Dougherty: We are makers', '1065')],
#  'Dalia Mogahed': [('Dalia Mogahed: What do you think when you look at me?',
#                     '2442'),
#                    ('Dalia Mogahed: The attitudes that sparked Arab Spring',
#                     '1462')],
#  'Dambisa Moyo': [("Dambisa Moyo: Economic growth has stalled. Let's fix it",
#                    '2423'),
#                   ('Dambisa Moyo: Is China the new idol for emerging '
#                    'economies?',
#                    '1842')],
#  'Dame Ellen MacArthur': [('Dame Ellen MacArthur: The surprising thing I '
#                            'learned sailing solo around the world',
#                            '2292')],
#  'Dame Stephanie Shirley': [('Dame Stephanie Shirley: Why do ambitious women '
#                              'have flat heads?',
#                              '2223')],
#  'Damian Palin': [('Damian Palin: Mining minerals from seawater', '1470')],
#  'Damon Horowitz': [('Damon Horowitz: Philosophy in prison', '1286'),
#                     ('Damon Horowitz: We need a "moral operating system"',
#                      '1162')],
#  'Dan Ariely': [("Dan Ariely: How equal do we want the world to be? You'd be "
#                  'surprised',
#                  '2229'),
#                 ('Dan Ariely: What makes us feel good about our work?', '1706'),
#                 ('Dan Ariely: Beware conflicts of interest', '1212'),
#                 ('Dan Ariely: Are we in control of our own decisions?', '548'),
#                 ('Dan Ariely: Our buggy moral code', '487')],
#  'Dan Barasch': [('Dan Barasch: A park underneath the hustle and bustle of New '
#                   'York City',
#                   '2078')],
#  'Dan Barber': [('Dan Barber: How I fell in love with a fish', '790'),
#                 ('Dan Barber: A foie gras parable', '406')],
#  'Dan Berkenstock': [('Dan Berkenstock: The world is one big dataset. Now, how '
#                       'to photograph it ...',
#                       '1919')],
#  'Dan Buettner': [('Dan Buettner: How to live to be 100+', '727')],
#  'Dan Cobley': [('Dan Cobley: What physics taught me about marketing', '941')],
#  'Dan Dennett': [('Dan Dennett: Cute, sexy, sweet, funny', '485'),
#                  ('Dan Dennett: Dangerous memes', '116'),
#                  ('Dan Dennett: The illusion of consciousness', '102'),
#                  ("Dan Dennett: Let's teach religion -- all religion -- in "
#                   'schools',
#                   '94')],
#  'Dan Gilbert': [('Dan Gilbert: The psychology of your future self', '2012'),
#                  ('Dan Gilbert: Why we make bad decisions', '420'),
#                  ('Dan Gilbert: The surprising science of happiness', '97')],
#  'Dan Gross': [("Dan Gross: Why gun violence can't be our new normal", '2472')],
#  'Dan Meyer': [('Dan Meyer: Math class needs a makeover', '855')],
#  'Dan Pacholke': [('Dan Pacholke: How prisons can help inmates live meaningful '
#                    'lives',
#                    '2057')],
#  'Dan Pallotta': [('Dan Pallotta: The way we think about charity is dead wrong',
#                    '1688')],
#  'Dan Phillips': [('Dan Phillips: Creative houses from reclaimed stuff',
#                    '1015')],
#  'Dan Pink': [('Dan Pink: The puzzle of motivation', '618')],
#  'Daniel Goldstein': [('Daniel Goldstein: The battle between your present and '
#                        'future self',
#                        '1310')],
#  'Daniel Goleman': [("Daniel Goleman: Why aren't we more compassionate?",
#                      '200')],
#  'Daniel H. Cohen': [('Daniel H. Cohen: For argument’s sake', '1805')],
#  'Daniel Kahneman': [('Daniel Kahneman: The riddle of experience vs. memory',
#                       '779')],
#  'Daniel Kish': [('Daniel Kish: How I use sonar to navigate the world',
#                   '2224')],
#  'Daniel Kraft': [("Daniel Kraft: Medicine's future? There's an app for that",
#                    '1168'),
#                   ('Daniel Kraft: A better way to harvest bone marrow', '601')],
#  'Daniel Levitin': [("Daniel Levitin: How to stay calm when you know you'll be "
#                      'stressed',
#                      '2361')],
#  'Daniel Libeskind': [('Daniel Libeskind: 17 words of architectural '
#                        'inspiration',
#                        '589')],
#  'Daniel Pauly': [("Daniel Pauly: The ocean's shifting baseline", '1373')],
#  'Daniel Reisel': [('Daniel Reisel: The neuroscience of restorative justice',
#                     '1946')],
#  'Daniel Suarez': [("Daniel Suarez: The kill decision shouldn't belong to a "
#                     'robot',
#                     '1766')],
#  'Daniel Tammet': [('Daniel Tammet: Different ways of knowing', '1175')],
#  'Daniel Wolpert': [('Daniel Wolpert: The real reason for brains', '1261')],
#  'Daniele Quercia': [('Daniele Quercia: Happy maps', '2162')],
#  'Danielle de Niese': [('Danielle de Niese: A flirtatious aria', '1235')],
#  'Danit Peleg': [("Danit Peleg: Forget shopping. Soon you'll download your new "
#                   'clothes',
#                   '2388')],
#  'Danny Hillis': [('Danny Hillis: The Internet could crash. We need a Plan B',
#                    '1693'),
#                   ('Danny Hillis: Back to the future (of 1994)', '1346'),
#                   ('Danny Hillis: Understanding cancer through proteomics',
#                    '1082')],
#  'Daphne Bavelier': [('Daphne Bavelier: Your brain on video games', '1618')],
#  'Daphne Koller': [("Daphne Koller: What we're learning from online education",
#                     '1531')],
#  'Daria van den Bercken': [('Daria van den Bercken: Why I take the piano on '
#                             'the road … and in the air',
#                             '2100')],
#  'Dave Eggers': [('Dave Eggers: My wish: Once Upon a School', '233')],
#  'Dave Isay': [('Dave Isay: Everyone around you has a story the world needs to '
#                 'hear',
#                 '2222')],
#  'Dave Meslin': [('Dave Meslin: The antidote to apathy', '1119')],
# ...
#                  ('Taryn Simon: Photographs of secret sites', '643')],
#  'Tasso Azevedo': [('Tasso Azevedo: Hopeful lessons from the battle to save '
#                     'rainforests',
#                     '2166')],
#  'Tavi Gevinson': [('Tavi Gevinson: A teen just trying to figure it out',
#                     '1438')],
#  'Taylor Wilson': [('Taylor Wilson: My radical plan for small nuclear fission '
#                     'reactors',
#                     '1727'),
#                    ('Taylor Wilson: Yup, I built a nuclear fusion reactor',
#                     '1397')],
#  'Teddy Cruz': [('Teddy Cruz: How architectural innovations migrate across '
#                  'borders',
#                  '1920')],
#  'Teitur': [("Teitur: Home is a song I've always remembered", '2345')],
#  'Temple Grandin': [('Temple Grandin: The world needs all kinds of minds',
#                      '773')],
#  'Terry Moore': [("Terry Moore: Why is 'x' the unknown?", '1469'),
#                  ('Terry Moore: How to tie your shoes', '1150')],
#  'Thandie Newton': [('Thandie Newton: Embracing otherness, embracing myself',
#                      '1193')],
#  'The LXD': [('The LXD: In the Internet age, dance evolves ...', '786')],
#  'The Lady Lifers': [('The Lady Lifers: A moving song from women in prison for '
#                       'life',
#                       '2250')],
#  'Theaster Gates': [('Theaster Gates: How to revive a neighborhood: with '
#                      'imagination, beauty and art',
#                      '2220')],
#  'Thelma Golden': [('Thelma Golden: How art gives shape to cultural change',
#                     '831')],
#  'Theo Jansen': [('Theo Jansen: My creations, a new form of life', '162')],
#  'They Might Be Giants': [('They Might Be Giants: Wake up!', '254')],
#  'Thom Mayne': [('Thom Mayne: How architecture can connect us', '31')],
#  'Thomas Barnett': [("Thomas Barnett: Let's rethink America's military "
#                      'strategy',
#                      '33')],
#  'Thomas Dolby': [('Thomas Dolby: "Love Is a Loaded Pistol"', '849')],
#  'Thomas Goetz': [("Thomas Goetz: It's time to redesign medical data", '1060')],
#  'Thomas Heatherwick': [('Thomas Heatherwick: Building the Seed Cathedral',
#                          '1147')],
#  'Thomas Hellum': [("Thomas Hellum: The world's most boring television ... and "
#                     "why it's hilariously addictive",
#                     '2148')],
#  'Thomas Insel': [('Thomas Insel: Toward a new understanding of mental illness',
#                    '1714')],
#  'Thomas P. Campbell': [('Thomas P. Campbell: Weaving narratives in museum '
#                          'galleries',
#                          '1579')],
#  'Thomas Peschak': [("Thomas Peschak: Dive into an ocean photographer's world",
#                      '2434')],
#  'Thomas Piketty': [('Thomas Piketty: New thoughts on capital in the '
#                      'twenty-first century',
#                      '2101')],
#  'Thomas Suarez': [('Thomas Suarez: A 12-year-old app developer', '1272')],
#  'Thomas Thwaites': [('Thomas Thwaites: How I built a toaster -- from scratch',
#                       '1051')],
#  'Thulasiraj Ravilla': [('Thulasiraj Ravilla: How low-cost eye care can be '
#                          'world-class',
#                          '709')],
#  'Tierney Thys': [('Tierney Thys: Swim with the giant sunfish', '126')],
#  'Tim Berners-Lee': [('Tim Berners-Lee: A Magna Carta for the web', '2061'),
#                      ('Tim Berners-Lee: The year open data went worldwide',
#                       '788'),
#                      ('Tim Berners-Lee: The next web', '484')],
#  'Tim Brown': [('Tim Brown: Designers -- think big!', '646'),
#                ('Tim Brown: Tales of creativity and play', '392')],
#  'Tim Ferriss': [('Tim Ferriss: Smash fear, learn anything', '517')],
#  'Tim Harford': [('Tim Harford: How messy problems can inspire creativity',
#                   '2401'),
#                  ('Tim Harford: Trial, error and the God complex', '1190')],
#  'Tim Jackson': [('Tim Jackson: An economic reality check', '972')],
#  'Tim Leberecht': [('Tim Leberecht: 3 ways to (usefully) lose control of your '
#                     'brand',
#                     '1591')],
#  'Tim Urban': [('Tim Urban: Inside the mind of a master procrastinator',
#                 '2458')],
#  'Timothy Bartik': [('Timothy Bartik: The economic case for preschool',
#                      '1735')],
#  'Timothy Prestero': [('Timothy Prestero: Design for people, not awards',
#                        '1549')],
#  'Toby Eccles': [('Toby Eccles: Invest in social change', '1881')],
#  'Toby Shapshak': [("Toby Shapshak: You don't need an app for that", '1944')],
#  'Tod Machover + Dan Ellsey': [('Tod Machover + Dan Ellsey: Inventing '
#                                 'instruments that unlock new music',
#                                 '246')],
#  'Todd Humphreys': [('Todd Humphreys: How to fool a GPS', '1507')],
#  'Todd Kuiken': [('Todd Kuiken: A prosthetic arm that "feels"', '1251')],
#  'Tom Chatfield': [('Tom Chatfield: 7 ways games reward the brain', '996')],
#  'Tom Honey': [('Tom Honey: Why would God create a tsunami?', '112')],
#  'Tom Rielly': [('Tom Rielly: A comic sendup of TED2006', '114')],
#  'Tom Shannon': [('Tom Shannon: Anti-gravity sculpture', '534')],
#  'Tom Shannon, John Hockenberry': [('Tom Shannon, John Hockenberry: The '
#                                     'painter and the pendulum',
#                                     '762')],
#  'Tom Thum': [('Tom Thum: The orchestra in my mouth', '1792')],
#  'Tom Uglow': [('Tom Uglow: An Internet without screens might look like this',
#                 '2356')],
#  'Tom Wujec': [('Tom Wujec: Got a wicked problem? First, tell me how you make '
#                 'toast',
#                 '2179'),
#                ('Tom Wujec: Build a tower, build a team', '837'),
#                ('Tom Wujec: Learn to use the 13th-century astrolabe', '694'),
#                ('Tom Wujec: 3 ways the brain creates meaning', '591')],
#  'Toni Griffin': [('Toni Griffin: A new vision for rebuilding Detroit',
#                    '1892')],
#  'Tony Fadell': [('Tony Fadell: The first secret of design is ... noticing',
#                   '2274')],
#  'Tony Porter': [('Tony Porter: A call to men', '1031')],
#  'Tony Robbins': [('Tony Robbins: Why we do what we do', '96')],
#  'Tony Wyss-Coray': [('Tony Wyss-Coray: How young blood might help reverse '
#                       'aging. Yes, really',
#                       '2315')],
#  'Topher White': [('Topher White: What can save the rainforest? Your used cell '
#                    'phone',
#                    '2203')],
#  'Torsten Reil': [('Torsten Reil: Animate characters by evolving them', '300')],
#  'Tracy Chevalier': [('Tracy Chevalier: Finding the story inside the painting',
#                       '1521')],
#  'Travis Kalanick': [("Travis Kalanick: Uber's plan to get more people into "
#                       'fewer cars',
#                       '2443')],
#  'Trevor Aaronson': [('Trevor Aaronson: How this FBI strategy is actually '
#                       'creating US-based terrorists',
#                       '2263')],
#  'Tristram Stuart': [('Tristram Stuart: The global food waste scandal',
#                       '1565')],
#  'Tristram Wyatt': [('Tristram Wyatt: The smelly mystery of the human '
#                      'pheromone',
#                      '2002')],
#  'Trita Parsi': [('Trita Parsi: Iran and Israel: Peace is possible', '1839')],
#  'Tshering Tobgay': [("Tshering Tobgay: This country isn't just carbon neutral "
#                       "-- it's carbon negative",
#                       '2452')],
#  'Tyler DeWitt': [('Tyler DeWitt: Hey science teachers -- make it fun',
#                    '1655')],
#  'Tyrone Hayes + Penelope Jagessar Chaffer': [('Tyrone Hayes + Penelope '
#                                                'Jagessar Chaffer: The toxic '
#                                                'baby',
#                                                '1356')],
#  'Ueli Gegenschatz': [('Ueli Gegenschatz: Extreme wingsuit flying', '502')],
#  'Uldus Bakhtiozina': [('Uldus Bakhtiozina: Wry photos that turn stereotypes '
#                         'upside down',
#                         '2089')],
#  'Uri Alon': [('Uri Alon: Why truly innovative science demands a leap into the '
#                'unknown',
#                '2020')],
#  'Ursus Wehrli': [('Ursus Wehrli: Tidying up art', '400')],
#  'Usman Riaz + Preston Reed': [('Usman Riaz + Preston Reed: A young guitarist '
#                                 'meets his hero',
#                                 '1500')],
#  'VS Ramachandran': [('VS Ramachandran: 3 clues to understanding your brain',
#                       '184')],
#  'Van Jones': [('Van Jones: The economic injustice of plastic', '1056')],
#  'Vernā Myers': [('Vernā Myers: How to overcome our biases? Walk boldly toward '
#                   'them',
#                   '2151')],
#  'Vicki Arroyo': [("Vicki Arroyo: Let's prepare for our new climate", '1583')],
#  'Vijay Kumar': [('Vijay Kumar: The future of flying robots', '2346'),
#                  ('Vijay Kumar: Robots that fly ... and cooperate', '1376')],
#  'Vik Muniz': [('Vik Muniz: Art with wire, sugar, chocolate and string', '32')],
#  'Vikram Patel': [('Vikram Patel: Mental health for all by involving all',
#                    '1557')],
#  'Vilayanur Ramachandran': [('Vilayanur Ramachandran: The neurons that shaped '
#                              'civilization',
#                              '724')],
#  'Vinay Venkatraman': [('Vinay Venkatraman: Technology crafts for the '
#                         'digitally underserved',
#                         '1516')],
#  'Vincent Cochetel': [('Vincent Cochetel: I was held hostage for 317 days. '
#                        "Here's what I thought about…",
#                        '2211')],
#  'Vincent Moon and Naná Vasconcelos': [('Vincent Moon and Naná Vasconcelos: '
#                                         'Hidden music rituals around the world',
#                                         '2131')],
#  'Virginia Postrel': [('Virginia Postrel: On glamour', '375')],
#  'Vusi Mahlasela': [('Vusi Mahlasela: "Thula Mama"', '158')],
#  'Wadah Khanfar': [('Wadah Khanfar: A historic moment in the Arab world',
#                     '1084')],
#  'Wade Davis': [('Wade Davis: The worldwide web of belief and ritual', '273'),
#                 ('Wade Davis: Dreams from endangered cultures', '69')],
#  'Wael Ghonim': [("Wael Ghonim: Let's design social media that drives real "
#                   'change',
#                   '2400'),
#                  ('Wael Ghonim: Inside the Egyptian revolution', '1086')],
#  'Wayne McGregor': [("Wayne McGregor: A choreographer's creative process in "
#                      'real time',
#                      '1527')],
#  'Wendy Chung': [('Wendy Chung: Autism — what we know (and what we don’t know '
#                   'yet)',
#                   '1985')],
#  'Wendy Freedman': [('Wendy Freedman: This new telescope might show us the '
#                      'beginning of the universe',
#                      '2320')],
#  'Wes Moore': [('Wes Moore: How to talk to veterans about the war', '2008')],
#  'Will Marshall': [('Will Marshall: Tiny satellites show us the Earth as it '
#                     'changes in near-real-time',
#                     '1982')],
#  'Will Potter': [("Will Potter: The secret US prisons you've never heard of "
#                   'before',
#                   '2352'),
#                  ('Will Potter: The shocking move to criminalize nonviolent '
#                   'protest',
#                   '2018')],
#  'Will Wright': [('Will Wright: Spore, birth of a game', '146')],
#  'Willard Wigan': [('Willard Wigan: Hold your breath for micro-sculpture',
#                     '610')],
#  'William Black': [('William Black: How to rob a bank (from the inside, that '
#                     'is)',
#                     '1996')],
#  'William Kamkwamba': [('William Kamkwamba: How I harnessed the wind', '642'),
#                        ('William Kamkwamba: How I built a windmill', '153')],
#  'William Li': [('William Li: Can we eat to starve cancer?', '859')],
#  'William McDonough': [('William McDonough: Cradle to cradle design', '104')],
#  'William Noel': [('William Noel: Revealing the lost codex of Archimedes',
#                    '1461')],
#  'William Ury': [('William Ury: The walk from "no" to "yes"', '1017')],
#  'Willie Smits': [('Willie Smits: How to restore a rainforest', '475')],
#  'Wingham Rowan': [('Wingham Rowan: A new kind of job market', '1656')],
#  'Wolfgang Kessling': [('Wolfgang Kessling: How to air-condition outdoor '
#                         'spaces',
#                         '1483')],
#  'Woody Norris': [('Woody Norris: Hypersonic sound and other inventions',
#                    '442')],
#  'Xavier Vilalta': [('Xavier Vilalta: Architecture at home in its community',
#                      '1854')],
#  'Yang Lan': [("Yang Lan: The generation that's remaking China", '1236')],
#  'Yanis Varoufakis': [('Yanis Varoufakis: Capitalism will eat democracy -- '
#                        'unless we speak up',
#                        '2413')],
#  'Yann Arthus-Bertrand': [('Yann Arthus-Bertrand: A wide-angle view of fragile '
#                            'Earth',
#                            '561')],
#  "Yann Dall'Aglio": [("Yann Dall'Aglio: Love -- you're doing it wrong",
#                       '1925')],
#  'Yasheng Huang': [('Yasheng Huang: Does democracy stifle economic growth?',
#                     '1220')],
#  'Yassmin Abdel-Magied': [('Yassmin Abdel-Magied: What does my headscarf mean '
#                            'to you?',
#                            '2262')],
#  'Yoav Medan': [('Yoav Medan: Ultrasound surgery -- healing without cuts',
#                  '1297')],
#  'Yochai Benkler': [('Yochai Benkler: The new open-source economics', '247')],
#  'Yoruba Richen': [('Yoruba Richen: What the gay rights movement learned from '
#                     'the civil rights movement',
#                     '2016')],
#  'Yossi Vardi': [("Yossi Vardi: We're worried about local warming ... in your "
#                   'lap',
#                   '203')],
#  'Young-ha Kim': [('Young-ha Kim: Be an artist, right now!', '1653')],
#  'Yuval Noah Harari': [('Yuval Noah Harari: What explains the rise of humans?',
#                         '2307')],
#  'Yves Behar': [('Yves Behar: A supercharged motorcycle design', '552'),
#                 ('Yves Behar: Designing objects that tell stories', '266')],
#  'Yves Morieux': [('Yves Morieux: How too many rules at work keep you from '
#                    'getting things done',
#                    '2321'),
#                   ('Yves Morieux: As work gets more complex, 6 rules to '
#                    'simplify',
#                    '1911')],
#  'Yves Rossy': [('Yves Rossy: Fly with the Jetman', '1271')],
#  'Zach Kaplan + Keith Schacht': [('Zach Kaplan + Keith Schacht: Toys and '
#                                   'materials from the future',
#                                   '385')],
#  "Zahra' Langhi": [("Zahra' Langhi: Why Libya's revolution didn't work -- and "
#                     'what might',
#                     '1659')],
#  'Zainab Salbi': [('Zainab Salbi: Women, wartime and the dream of peace',
#                    '1013')],
#  'Zak Ebrahim': [("Zak Ebrahim: I am the son of a terrorist. Here's how I "
#                   'chose peace.',
#                   '2024')],
#  'Ze Frank': [('Ze Frank: Are you human?', '2049'),
#               ('Ze Frank: My web playroom', '981'),
#               ('Ze Frank: Nerdcore comedy', '87')],
#  'Zeresenay Alemseged': [("Zeresenay Alemseged: The search for humanity's "
#                           'roots',
#                           '168')],
#  'Zeynep Tufekci': [('Zeynep Tufekci: Online social change: easy to organize, '
#                      'hard to win',
#                      '2176')],
#  'Ziauddin Yousafzai': [('Ziauddin Yousafzai: My daughter, Malala', '1954')],
#  'Ziyah Gafić': [('Ziyah Gafić: Everyday objects, tragic histories', '2063')],
#  'eL Seed': [('eL Seed: Street art with a message of hope and peace', '2304')],
#  'iO Tillett Wright': [('iO Tillett Wright: Fifty shades of gay', '1658')]}

# %% [markdown]
# # Part II: Analyze the translations
#
# This part of the assignment requires you to compare information accross multiple files.
#
# * Which language has the most translations? Which language has the least translations?
#
# * Which talk(s) is (are) translated into most languages? Please provide the English title(s) and the talk ids.
#
# * BONUS (just for fun - no points): What is the word for 'applaus' in the languages represented in the corpus?
#
#
# Please create a script called `ted_translation_analysis.py`. The script should print answers to the questions above. You can reuse (import, copy, modify) functions you created for Part I.
#
# Below, you will find several steps that guide you through the assignment. Code following these steps will earn you points (even if you do not manage to get the correct final output).

# %% [markdown]
# ### Step 1. Map languages to filepaths (x points)
#
# Answering the questions above will require you to load and analyze xml files containing the translations of the English talks. It will be useful to have a dictionary that maps languages to filepaths. For example, the dictionary should contain the following entries:
#
# ```
# {
#     'nl' :  '../Data/ted-talks/XML_releases/xml/ted_nl-20160408.xml',
#     'it' : '../Data/ted-talks/XML_releases/xml/ted_it-20160408.xml',
#     'fr-ca': '../Data/ted-talks/XML_releases/xml/ted_fr-ca-20160408.xml',
#     ...
# }
# ```
# You can use the os or glob package to get a list of all filepaths in the directory `../Data/ted-talks/XML_releases/xml/`. Note that the language is provided between `ted_` and the release information (`-20160408`). Use string manipulation to access the language information. Attention: Some languages contain a hyphen (e.g. Canadian French fr-ca).
#
# In this assignment, you do not have to spell out the languages. It is alright if you provide the shortened names as they appear in the filepaths.
#
# Write a function (called `map_languages_to_paths`) that returns the dictionary.

# %%
# Example string manipulation (feel free to choose a different strategy)
lang_id = 'fr-ca-20160408'
rev = lang_id[::-1]
# split only at first point:
f_id, lang = rev.split('-', 1)
lang[::-1]
# Out:
# 'fr-ca'

# %% [markdown]
# ### Step 2: Write a function which returns the language with the most/least translations
#
# Name: `find_coverage`
#
# Input:
#
# * dictionary mapping languages to paths (positional)
# * most/least languages (e.g. 'most', 'least') (positional)
#
# Output:
#
# * a dictionary with language(s) (keys) and the respective number of tranlated talks (values)
#
#
# Tip: You can simply check the number of talks in each xml file corresponding to a language.

# %% [markdown]
# ### Step 3: Map talk ids to titles
#
# You can use talk ids to map English talks to their translations in other languages. Most of your code will work with these ids. In the end, you should map talk ids to titles.
#
# Write a function called `get_id_title_dict` that maps talk ids to English titles. Your function should take the path to the English file as input and return a dictionary (keys: talk ids, values: English talk titles).
#
# Tip: Reuse functions from the previous assignment.

# %% [markdown]
# ### Step 4 Map talks to languages they have been translated into
#
# Function name: Map_talks_to_languages
#
# Input: language filepath dict (result of Step 1)
#
# Output: a dictionary mapping talk ids to languages with translations of the talk. The dictionary should have the following structure (the example is made up):
#
# ```
# {
#     '10': ['hy', 'nl', 'de', 'fr-ca']
#     '20': ['pl', 'da', 'nl', 'oc', 'ar']
#
# }
#
# ```
#
#
# Tip: You can use defaultdict for this step.

# %% [markdown]
# ### Step 5: Map number of languages to talks
#
# Goal: You want to know which talks haven been translated into how many languages. In the next step, you will want to rank talks by how many languages they've been translated into (or directly get the highest or lowest number of translations). To do this, it is useful to have a mapping from the number of translations to the talk ids
#
# Function name: map_nlang_to_talks
#
# Input: dictionary mapping talk ids to languages (list)
#
# Output: dictionary mapping number of translations (int) to talks (list of talk ids) having the following structure (this is not the correct output - just an example of the structure):
#
# ```
# {
#
#     30 : ['200', '10', '31']
#     29 : ['201', '9', '7']
#     47 : ['1', '14', '209', '5']
#
# }
#
# ```

# %% [markdown]
# ### Step 6: Put it all together
#
# Put the functions you wrote above together to find the talk(s) that has (have) been translated into the most or least languages
#
# Name: find_top_coverage
#
# Input:
#     * dict mapping languages to filepaths (created in Step 1)
#     * most or least translations ('most' or 'least')
#
# Output: A dictionary mapping the most/least talk titles to the languages they have been translated into. For example (this is not the correct solution - we just use it to show the structure):
#
# ```
# {
#     'Dan Gross: Why gun violence can't be our new normal' : ['de', 'nl', 'it']
#     'Angélica Dass: The beauty of human skin in every color': ['fr-ca', 'de', 'ceb']
#
#
# }
# ```
#
# Use the output to print the correct solution to the terminal. (Tip: Call the same function twice - once for the most translations, once for the least translations)
#
#
# **Code structure:**
#
# Your functions should be called in the script called `ted_translation_analysis.py`. If you used helper functions (recommended), please store them in utils.py and import them.
#
# **Informative print statements**
#
# Please add print statements so the output can be interpreted. See instructions for Part 1.
#
#
# **Grading**
#
# You will receive points for the functions,  the print statements, and the script.

# %%
# !python ted_translation_analysis.py
# Out:
#  The mapping of languages to paths : {'hup': '../Data/ted-talks/XML_releases/xml/ted_hup-20160408.xml', 'as': '../Data/ted-talks/XML_releases/xml/ted_as-20160408.xml', 'ml': '../Data/ted-talks/XML_releases/xml/ted_ml-20160408.xml', 'szl': '../Data/ted-talks/XML_releases/xml/ted_szl-20160408.xml', 'is': '../Data/ted-talks/XML_releases/xml/ted_is-20160408.xml', 'eu': '../Data/ted-talks/XML_releases/xml/ted_eu-20160408.xml', 'el': '../Data/ted-talks/XML_releases/xml/ted_el-20160408.xml', 'uz': '../Data/ted-talks/XML_releases/xml/ted_uz-20160408.xml', 'nb': '../Data/ted-talks/XML_releases/xml/ted_nb-20160408.xml', 'lb': '../Data/ted-talks/XML_releases/xml/ted_lb-20160408.xml', 'ar': '../Data/ted-talks/XML_releases/xml/ted_ar-20160408.xml', 'ltg': '../Data/ted-talks/XML_releases/xml/ted_ltg-20160408.xml', 'inh': '../Data/ted-talks/XML_releases/xml/ted_inh-20160408.xml', 'rup': '../Data/ted-talks/XML_releases/xml/ted_rup-20160408.xml', 'mk': '../Data/ted-talks/XML_releases/xml/ted_mk-20160408.xml', 'ca': '../Data/ted-talks/XML_releases/xml/ted_ca-20160408.xml', 'ig': '../Data/ted-talks/XML_releases/xml/ted_ig-20160408.xml', 'ms': '../Data/ted-talks/XML_releases/xml/ted_ms-20160408.xml', 'srp': '../Data/ted-talks/XML_releases/xml/ted_srp-20160408.xml', 'bs': '../Data/ted-talks/XML_releases/xml/ted_bs-20160408.xml', 'si': '../Data/ted-talks/XML_releases/xml/ted_si-20160408.xml', 'cnh': '../Data/ted-talks/XML_releases/xml/ted_cnh-20160408.xml', 'ne': '../Data/ted-talks/XML_releases/xml/ted_ne-20160408.xml', 'nl': '../Data/ted-talks/XML_releases/xml/ted_nl-20160408.xml', 'hu': '../Data/ted-talks/XML_releases/xml/ted_hu-20160408.xml', 'tlh': '../Data/ted-talks/XML_releases/xml/ted_tlh-20160408.xml', 'mg': '../Data/ted-talks/XML_releases/xml/ted_mg-20160408.xml', 'ps': '../Data/ted-talks/XML_releases/xml/ted_ps-20160408.xml', 'ta': '../Data/ted-talks/XML_releases/xml/ted_ta-20160408.xml', 'da': '../Data/ted-talks/XML_releases/xml/ted_da-20160408.xml', 'be': '../Data/ted-talks/XML_releases/xml/ted_be-20160408.xml', 'sw': '../Data/ted-talks/XML_releases/xml/ted_sw-20160408.xml', 'km': '../Data/ted-talks/XML_releases/xml/ted_km-20160408.xml', 'ru': '../Data/ted-talks/XML_releases/xml/ted_ru-20160408.xml', 'art-x-bork': '../Data/ted-talks/XML_releases/xml/ted_art-x-bork-20160408.xml', 'sl': '../Data/ted-talks/XML_releases/xml/ted_sl-20160408.xml', 'kk': '../Data/ted-talks/XML_releases/xml/ted_kk-20160408.xml', 'sv': '../Data/ted-talks/XML_releases/xml/ted_sv-20160408.xml', 'de': '../Data/ted-talks/XML_releases/xml/ted_de-20160408.xml', 'la': '../Data/ted-talks/XML_releases/xml/ted_la-20160408.xml', 'pl': '../Data/ted-talks/XML_releases/xml/ted_pl-20160408.xml', 'uk': '../Data/ted-talks/XML_releases/xml/ted_uk-20160408.xml', 'th': '../Data/ted-talks/XML_releases/xml/ted_th-20160408.xml', 'gl': '../Data/ted-talks/XML_releases/xml/ted_gl-20160408.xml', 'hr': '../Data/ted-talks/XML_releases/xml/ted_hr-20160408.xml', 'sh': '../Data/ted-talks/XML_releases/xml/ted_sh-20160408.xml', 'oc': '../Data/ted-talks/XML_releases/xml/ted_oc-20160408.xml', 'my': '../Data/ted-talks/XML_releases/xml/ted_my-20160408.xml', 'lt': '../Data/ted-talks/XML_releases/xml/ted_lt-20160408.xml', 'et': '../Data/ted-talks/XML_releases/xml/ted_et-20160408.xml', 'mt': '../Data/ted-talks/XML_releases/xml/ted_mt-20160408.xml', 'arq': '../Data/ted-talks/XML_releases/xml/ted_arq-20160408.xml', 'it': '../Data/ted-talks/XML_releases/xml/ted_it-20160408.xml', 'pt': '../Data/ted-talks/XML_releases/xml/ted_pt-20160408.xml', 'af': '../Data/ted-talks/XML_releases/xml/ted_af-20160408.xml', 'te': '../Data/ted-talks/XML_releases/xml/ted_te-20160408.xml', 'en': '../Data/ted-talks/XML_releases/xml/ted_en-20160408.xml', 'sr': '../Data/ted-talks/XML_releases/xml/ted_sr-20160408.xml', 'ga': '../Data/ted-talks/XML_releases/xml/ted_ga-20160408.xml', 'ky': '../Data/ted-talks/XML_releases/xml/ted_ky-20160408.xml', 'am': '../Data/ted-talks/XML_releases/xml/ted_am-20160408.xml', 'id': '../Data/ted-talks ...
#
#  Least coverage: None
#
#  Most coverage: {'en': 2085}
#
#  The id title dict for 'en': {'2470': 'Knut Haanaes: Two reasons companies fail -- and how to avoid them', '2471': 'Lisa Nip: How humans could evolve to survive in space', '2472': "Dan Gross: Why gun violence can't be our new normal", '2463': 'Angélica Dass: The beauty of human skin in every color', '2461': 'Alex Kipman: A futuristic vision of the age of holograms', '2462': 'Siyanda Mohutsiwa: How young Africans found a voice on Twitter', '2455': 'Latif Nasser: You have no idea where camels really come from', '2469': 'Carol Fishman Cohen: How to get back to work after a career break', '2453': "Adam Foss: A prosecutor's vision for a better justice system", '2459': 'Meron Gribetz: A glimpse of the future through an augmented reality headset', '2456': "Arthur Brooks: A conservative's plea: Let's work together", '2457': 'Jessica Ladd: The reporting system that sexual assault survivors want', '2458': 'Tim Urban: Inside the mind of a master procrastinator', '2447': 'Joe Gebbia: How Airbnb designs for trust', '2451': 'Casey Gerald: The gospel of doubt', '2452': "Tshering Tobgay: This country isn't just carbon neutral -- it's carbon negative", '2454': "Mileha Soneji: Simple hacks for life with Parkinson's", '2390': 'Laura Robinson: The secrets I find on the mysterious ocean floor', '2432': 'Caleb Harper: This computer will grow your food in the future', '2448': 'Reshma Saujani: Teach girls bravery, not perfection', '2443': "Travis Kalanick: Uber's plan to get more people into fewer cars", '2449': "Alexander Betts: Our refugee system is failing. Here's how we can fix it", '2436': 'Russ Altman: What really happens when you mix medications?', '2437': 'Magda Sayeg: How yarn bombing grew into a worldwide movement', '2434': "Thomas Peschak: Dive into an ocean photographer's world", '2433': 'Ivan Coyote: Why we need gender-neutral bathrooms', '2445': 'Mary Bassett: Why your doctor should care about social justice', '2431': 'Audrey Choi: How to make a profit while making a difference', '2442': 'Dalia Mogahed: What do you think when you look at me?', '2441': 'Al Gore: The case for optimism on climate change', '2440': "Raffaello D'Andrea: Meet the dazzling flying machines of the future", '2439': 'Allan Adams: What the discovery of gravitational waves means', '2438': 'Shonda Rhimes: My year of saying yes to everything', '2435': 'Celeste Headlee: 10 ways to have a better conversation', '2429': 'Jocelyne Bloch: The brain may be able to repair itself -- with help', '2428': 'Dorothy Roberts: The problem with race-based medicine', '2427': 'Mike Velings: The case for fish farming', '2430': "Gregory Heyworth: How I'm discovering the secrets of ancient texts", '2410': 'Sean Follmer: Shape-shifting tech will change work as we know it', '2423': "Dambisa Moyo: Economic growth has stalled. Let's fix it", '2426': 'Matthew Williams: Special Olympics let me be myself -- a champion', '2425': "Pardis Sabeti: How we'll fight the next deadly virus", '2420': 'Judson Brewer: A simple way to break a bad habit', '2424': 'Andrés Ruzo: How I found a mythical boiling river in the Amazon', '2417': 'Linda Liukas: A delightful way to teach kids about computers', '2418': 'Melati and Isabel Wijsen: Our campaign to ban plastic bags in Bali', '2419': 'Auke Ijspeert: A robot that runs and swims like a salamander', '2416': 'Tania Simoncelli: Should you be able to patent a human gene?', '2414': 'David Gruber: Glow-in-the-dark sharks and other stunning sea creatures', '2413': 'Yanis Varoufakis: Capitalism will eat democracy -- unless we speak up', '2415': 'Elizabeth Lev: The unheard story of the Sistine Chapel', '2407': 'Achenyo Idachaba: How I turned a deadly plant into a thriving business', '2411': 'Oscar Schwartz: Can a computer write poetry?', '2412': 'Jill Farrant: How we can make crops survive without water', '2409': 'Jill Heinerth: The mysterious world of underwater caves', '2375': 'Ole Scheeren: Why great architecture should tell a story', '2400': "Wael Ghonim: Let's design ...
#  The mapping of talks to languages: {'179': ['hup', 'eu', 'el', 'nb', 'ar', 'nl', 'hu', 'ru', 'sl', 'sv', 'de', 'pl', 'uk', 'th', 'hr', 'my', 'lt', 'mt', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'es', 'fr', 'ko', 'bg', 'az', 'zh-tw', 'he', 'tr', 'ka', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'lv', 'pt-br', 'ro', 'ja'], '407': ['as', 'el', 'uz', 'nb', 'ar', 'ca', 'nl', 'hu', 'ta', 'da', 'ru', 'sl', 'sv', 'de', 'pl', 'uk', 'th', 'hr', 'my', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'mr', 'vi', 'fi', 'sq', 'fa', 'cs', 'pt-br', 'hi', 'ro', 'ja'], '2409': ['ml', 'el', 'ar', 'mk', 'nl', 'be', 'ru', 'th', 'hr', 'my', 'lt', 'pt', 'en', 'sr', 'es', 'ko', 'he', 'zh-cn', 'sq', 'fa', 'pt-br', 'hi'], '2096': ['ml', 'el', 'ar', 'ca', 'nl', 'hu', 'da', 'ru', 'sv', 'de', 'pl', 'uk', 'th', 'hr', 'my', 'lt', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'fr-ca', 'es', 'mn', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'fa', 'cs', 'lv', 'pt-br', 'ro', 'ja'], '2068': ['ml', 'el', 'ar', 'nl', 'ru', 'sv', 'de', 'uk', 'th', 'lt', 'it', 'pt', 'en', 'sr', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'fa', 'pt-br', 'ro', 'ja'], '1971': ['ml', 'el', 'ar', 'nl', 'ru', 'sl', 'de', 'pl', 'uk', 'th', 'hr', 'my', 'it', 'pt', 'en', 'sr', 'id', 'ur', 'es', 'fr', 'ko', 'zh-tw', 'he', 'tr', 'zh', 'zh-cn', 'vi', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1866': ['ml', 'el', 'ar', 'nl', 'hu', 'da', 'ru', 'sv', 'de', 'pl', 'th', 'hr', 'it', 'en', 'sr', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh', 'zh-cn', 'mr', 'vi', 'sq', 'fa', 'cs', 'pt-br', 'hi', 'ro', 'ja'], '1864': ['ml', 'el', 'ar', 'nl', 'hu', 'ru', 'de', 'pl', 'uk', 'th', 'it', 'pt', 'en', 'sr', 'id', 'so', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'ku', 'pt-br', 'ro', 'ja'], '1862': ['ml', 'el', 'ar', 'ca', 'ms', 'bs', 'nl', 'hu', 'ta', 'da', 'ru', 'sl', 'de', 'pl', 'uk', 'th', 'hr', 'my', 'lt', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'fr-ca', 'es', 'mn', 'fr', 'ko', 'bg', 'zh-tw', 'gu', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1858': ['ml', 'el', 'ar', 'ca', 'nl', 'da', 'sw', 'ru', 'de', 'pl', 'th', 'hr', 'it', 'pt', 'en', 'sr', 'id', 'bn', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1857': ['ml', 'eu', 'el', 'ar', 'mk', 'ca', 'nl', 'hu', 'ta', 'ru', 'de', 'pl', 'uk', 'pt', 'en', 'sr', 'id', 'sk', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'fa', 'pt-br', 'ro', 'ja'], '1826': ['ml', 'el', 'ar', 'mk', 'nl', 'hu', 'ru', 'sv', 'de', 'pl', 'th', 'hr', 'it', 'pt', 'en', 'sr', 'sk', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1767': ['ml', 'el', 'ar', 'ca', 'nl', 'hu', 'ru', 'sv', 'de', 'pl', 'uk', 'hr', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1557': ['ml', 'el', 'ar', 'mk', 'nl', 'ru', 'de', 'pl', 'uk', 'hr', 'it', 'pt', 'en', 'sr', 'id', 'es', 'fr', 'ko', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'fa', 'pt-br', 'ro', 'ja'], '1381': ['ml', 'el', 'ar', 'nl', 'hu', 'ru', 'de', 'pl', 'uk', 'th', 'gl', 'hr', 'it', 'pt', 'en', 'sr', 'sk', 'fr-ca', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fil', 'fa', 'cs', 'pt-br', 'hi', 'ro', 'ja'], '1368': ['ml', 'el', 'ar', 'ca', 'nl', 'hu', 'ru', 'sl', 'de', 'pl', 'uk', 'th', 'hr', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'fr-ca', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'hy', 'fa', 'cs', 'pt-br', 'ro', 'ja'], '1327': ['ml', 'eu', 'el', 'ar', 'mk', 'bs', 'nl', 'hu', 'da', 'ru', 'sl', 'sv', 'de', 'pl', 'uk', 'th', 'hr', 'lt', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'fr-ca', 'es', 'fr', 'ko', 'bg', 'zh-tw', 'he', 'tr', 'zh-cn', 'vi', 'sq', 'fa', 'cs', 'lv', 'pt-br', 'hi', 'ro', 'ja'], '1071': ['ml', 'el', 'ar', 'ms', 'nl', 'hu', 'ru', 'sl', 'de', 'pl', 'uk', 'hr', 'it', 'pt', 'en', 'sr', 'id', 'sk', 'so', 'tg', 'fr-ca', 'es' ...
#
#  Mapping of no. of languages to talks: {42: ['179', '1327', '113', '1109', '97', '481', '2012', '1733', '1725', '1699', '1634', '1390', '1262', '618', '482'], 43: ['407', '1862', '1203', '2200', '2049', '1797', '1553', '1397', '1377', '1344', '1195', '1090', '949', '893', '848', '199', '123', '1'], 22: ['2409', '84', '2373', '2357', '2352', '2343', '2335', '2328', '2226', '2214', '2127', '2098', '2074', '2060', '2055', '2035', '2000', '1972', '1948', '1845', '1872', '1793', '1768', '1752', '1721', '1642', '1625', '1623', '1593', '1559', '1481', '1370', '1356', '1350', '1346', '1251', '1186', '1082', '1011', '1003', '879', '845', '842', '688', '670', '558', '469', '315', '270', '174', '212', '198', '1545', '64', '2407', '2401', '2395', '2327', '2315', '2263', '2224', '2094', '2013', '1783', '1627', '1571', '1556', '1457', '1434', '1302', '1009', '950', '939', '929', '898', '886', '833', '823', '772', '705', '696', '648', '570', '537', '433', '405', '396', '232', '222', '210', '51', '5', '44', '36', '38', '56', '27'], 39: ['2096', '2273', '2212', '2161', '2095', '2059', '1730', '1647', '1482', '1269', '1246', '1239', '1228', '1206', '1192', '1178', '1161', '1144', '987', '957', '752', '555', '531', '287', '149'], 27: ['2068', '1557', '294', '40', '360', '2227', '2381', '2338', '2324', '2310', '2301', '2303', '2293', '2280', '2277', '2276', '2243', '2228', '2234', '2231', '2152', '2182', '2178', '2164', '1982', '2134', '2078', '2053', '2044', '2001', '2011', '1981', '1922', '1905', '1876', '1874', '1860', '1854', '1848', '1820', '1811', '1813', '1761', '1762', '1766', '1760', '1743', '1720', '1715', '1707', '1688', '1657', '1652', '1618', '1583', '1576', '1565', '1549', '1517', '1514', '1496', '1485', '1478', '1468', '1458', '1420', '1419', '1345', '1291', '1256', '1237', '1152', '1113', '1088', '1076', '1070', '1060', '1054', '978', '972', '952', '938', '927', '920', '881', '836', '776', '701', '623', '619', '604', '560', '498', '484', '404', '325', '266', '147', '110', '81', '61', '47', '2', '54', '1865', '118', '2319', '2179', '2145', '1934', '1166', '1001', '1000', '847', '751', '573', '411', '308', '194', '76', '65'], 32: ['1971', '1864', '163', '1007', '663', '959', '103', '2382', '2366', '2245', '2236', '2238', '2237', '2184', '2149', '2146', '2122', '2114', '2050', '2045', '2023', '1961', '1955', '1923', '1930', '1828', '1722', '1764', '1737', '1724', '1665', '1655', '1651', '1624', '1607', '1591', '1542', '1508', '1447', '1339', '1308', '1266', '1236', '1199', '1177', '1172', '1158', '1142', '1136', '1086', '1084', '1072', '1067', '1049', '1043', '1036', '1020', '1018', '995', '986', '963', '911', '894', '878', '868', '855', '838', '818', '809', '792', '788', '769', '727', '710', '658', '654', '633', '626', '613', '594', '525', '523', '473', '381', '366', '307', '292', '225', '82', '115', '74', '1288', '62'], 33: ['1866', '1858', '1767', '1226', '2388', '2256', '2221', '2204', '2193', '2180', '2171', '2162', '2031', '2017', '1987', '1962', '1944', '1936', '1903', '1891', '1798', '1794', '1772', '1683', '1646', '1636', '1631', '1610', '1620', '1619', '1584', '1575', '1564', '1449', '1443', '1409', '1403', '1376', '1305', '1295', '1247', '1233', '1231', '1213', '1208', '1197', '1133', '1116', '1115', '1112', '1104', '1094', '1092', '1059', '1010', '974', '966', '961', '917', '915', '887', '877', '876', '837', '805', '748', '744', '741', '719', '704', '660', '657', '630', '620', '602', '566', '518', '364', '272', '261', '241', '142', '16', '2399', '2244', '2240', '200'], 31: ['1857', '1826', '2342', '2307', '2295', '2281', '2251', '2215', '2183', '2150', '2144', '2089', '2067', '2052', '2047', '2036', '1973', '1965', '1963', '1942', '1918', '1910', '1894', '1877', '1873', '1852', '1836', '1833', '1823', '1818', '1804', '1785', '1782', '1759', '1746', '1734', '1714', '1703', '1670', '1671', '1668', '1643', '1621', '1606', '1563', '1500', '1441', '1436', '1426', '1422', '1411', '1379', '1378', '1359', '1337', '1314', '1297',  ...
#  Top most coverage: {'Matt Cutts: Try something new for 30 days': ['el', 'uz', 'nb', 'ar', 'ltg', 'mk', 'ca', 'ms', 'si', 'nl', 'hu', 'ta', 'da', 'be', 'ru', 'sl', 'kk', 'sv', 'de', 'pl', 'uk', 'th', 'gl', 'hr', 'my', 'lt', 'et', 'arq', 'it', 'pt', 'te', 'en', 'sr', 'ky', 'id', 'sk', 'tg', 'fr-ca', 'eo', 'bn', 'es', 'mn', 'fr', 'ko', 'bg', 'ug', 'az', 'tl', 'zh-tw', 'he', 'tr', 'ka', 'zh', 'zh-cn', 'mr', 'vi', 'fi', 'sq', 'fil', 'tt', 'hy', 'fa', 'cs', 'lv', 'pt-br', 'hi', 'ro', 'ja'], 'Derek Sivers: Weird, or just different?': ['el', 'uz', 'nb', 'ar', 'ltg', 'mk', 'ca', 'ms', 'nl', 'hu', 'ta', 'da', 'be', 'ru', 'sl', 'sv', 'de', 'pl', 'uk', 'th', 'gl', 'hr', 'oc', 'my', 'lt', 'et', 'it', 'pt', 'af', 'en', 'sr', 'am', 'id', 'sk', 'ur', 'fr-ca', 'eo', 'bn', 'es', 'mn', 'fr', 'ko', 'bg', 'az', 'tl', 'bo', 'zh-tw', 'he', 'tr', 'ka', 'zh', 'zh-cn', 'mr', 'vi', 'fi', 'sq', 'tt', 'hy', 'fa', 'cs', 'ku', 'lv', 'ceb', 'ast', 'pt-br', 'hi', 'ro', 'ja']}
#
#  Top least coverage: {'Siyanda Mohutsiwa: How young Africans found a voice on Twitter': ['en'], "Adam Foss: A prosecutor's vision for a better justice system": ['en']}
